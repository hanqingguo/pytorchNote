# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %%
criterion = nn.CrossEntropyLoss()

# %%
output = torch.rand(1,3)

# %%
target = torch.Tensor([0])

# %%
output
# Out:
# tensor([[ 0.7576,  0.2793,  0.4031]])

# %%
target.size()
# Out:
# torch.Size([1])

# %%
output
# Out:
# tensor([[ 0.7576,  0.2793,  0.4031]])

# %%
_, pred = torch.max(output, 1)

# %%
pred
# Out:
# tensor([ 0])

# %%
a = torch.Tensor([2.])

# %%
a
# Out:
# tensor([ 2.])

# %%
a.item()
# Out:
# 2.0

# %%
pred.item()
# Out:
# 0

# %%
a.item() == pred.item()
# Out:
# False

# %%
print("\%")
# Out:
# \%

# %%
import numpy as np

# %%
a = np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,a)
plt.show()

# %%
w = torch.randn(3, 5)

# %%
w
# Out:
# tensor([[ 0.7244, -0.7022,  1.1661,  0.2605,  0.3506],
#         [ 1.0203, -1.8349, -2.2149,  0.0436,  1.3240],
#         [-0.1005,  0.6443,  0.5244,  1.0157,  0.2571]])

# %%
nn.init.orthogonal_(w)
# Out:
# tensor([[-0.5867,  0.5298,  0.2520,  0.3527,  0.4327],
#         [ 0.4944, -0.1314,  0.3586,  0.7807, -0.0140],
#         [ 0.3486, -0.1315,  0.3837, -0.4059,  0.7411]])

# %%
training_data = [
    ("The dog ate the apple".split(), ["DET", "NN", "V", "DET", "NN"]),
    ("Everybody read that book".split(), ["NN", "V", "DET", "NN"])
]

# %%
training_data
# Out:
# [(['The', 'dog', 'ate', 'the', 'apple'], ['DET', 'NN', 'V', 'DET', 'NN']),
#  (['Everybody', 'read', 'that', 'book'], ['NN', 'V', 'DET', 'NN'])]

# %%
word_to_ix = {} # 单词的索引字典
for sent, tags in training_data:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
print(word_to_ix)
# Out:
# {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'that': 7, 'book': 8}

# %%
tag_to_ix = {"DET": 0, "NN": 1, "V": 2} # 手工设定词性标签数据字典
EMBEDDING_DIM = 6
HIDDEN_DIM = 6

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)
        self.hidden = self.init_hidden()

    def init_hidden(self):
        # Before we've done anything, we dont have any hidden state.
        # Refer to the Pytorch documentation to see exactly
        # why they have this dimensionality.
        # The axes semantics are (num_layers, minibatch_size, hidden_dim)
        return (torch.zeros(1, 1, self.hidden_dim),
                torch.zeros(1, 1, self.hidden_dim))

    def forward(self, sentence):
        print("sentence is {}".format(sentence))
        embeds = self.word_embeddings(sentence)
        print("embeds is {}".format(embeds))
        lstm_out, self.hidden = self.lstm(
            embeds.view(len(sentence), 1, -1), self.hidden)
        tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
        print("tag_space is \n{}\n, tag_space.size is \n{}\n".format(tag_space, tag_space.size()))
        tag_scores = F.log_softmax(tag_space, dim=1)
        print("tag_scores is \n{}\n, tag_scores.size is \n{}\n".format(tag_scores, tag_scores.size()))
        return tag_scores

# %%
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix), len(tag_to_ix))
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# See what the scores are before training
# Note that element i,j of the output is the score for tag j for word i.
# Here we don't need to train, so the code is wrapped in torch.no_grad()
with torch.no_grad():
    inputs = prepare_sequence(training_data[0][0], word_to_ix)
    tag_scores = model(inputs)
    print(tag_scores)

for epoch in range(300):  # again, normally you would NOT do 300 epochs, it is toy data
    for sentence, tags in training_data:
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Also, we need to clear out the hidden state of the LSTM,
        # detaching it from its history on the last instance.
        model.hidden = model.init_hidden()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.
        sentence_in = prepare_sequence(sentence, word_to_ix)
        targets = prepare_sequence(tags, tag_to_ix)

        # Step 3. Run our forward pass.
        tag_scores = model(sentence_in)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = loss_function(tag_scores, targets)
        print("loss is \n\n{}\n".format(loss))
        print("tag_scores is \n\n{}\n, targets is \n\n{}\n".format(tag_scores, targets))
        loss.backward()
        optimizer.step()

# See what the scores are after training
with torch.no_grad():
    inputs = prepare_sequence(training_data[0][0], word_to_ix)
    tag_scores = model(inputs)

    # The sentence is "the dog ate the apple".  i,j corresponds to score for tag j
    # for word i. The predicted tag is the maximum scoring tag.
    # Here, we can see the predicted sequence below is 0 1 2 0 1
    # since 0 is index of the maximum value of row 1,
    # 1 is the index of maximum value of row 2, etc.
    # Which is DET NOUN VERB DET NOUN, the correct sequence!
    print(tag_scores)
# Out:
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2576, -1.1939,  0.1850,  0.9681,  0.7885,  0.7886],
#         [-1.0262, -2.1640, -0.9712,  0.0790, -0.5852, -0.9922],
#         [-1.0164, -1.6938,  1.6908, -0.2834, -0.8296, -0.4889],
#         [-0.5493,  0.0920, -0.1315,  0.1374,  0.8363,  1.2527],
#         [ 0.1292,  1.5971,  0.8172,  0.0666, -0.8052, -0.4801]])
# tag_space is
# tensor([[-0.1663,  0.1064, -0.2628],
#         [-0.1388,  0.0170, -0.3017],
#         [-0.1074, -0.0396, -0.2060],
#         [-0.2053,  0.0895, -0.2832],
#         [-0.3295, -0.0609, -0.4147]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1698, -0.8972, -1.2664],
#         [-1.1047, -0.9489, -1.2675],
#         [-1.0906, -1.0229, -1.1893],
#         [-1.1842, -0.8894, -1.2620],
#         [-1.1714, -0.9028, -1.2566]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# tensor([[-1.1698, -0.8972, -1.2664],
#         [-1.1047, -0.9489, -1.2675],
#         [-1.0906, -1.0229, -1.1893],
#         [-1.1842, -0.8894, -1.2620],
#         [-1.1714, -0.9028, -1.2566]])
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2576, -1.1939,  0.1850,  0.9681,  0.7885,  0.7886],
#         [-1.0262, -2.1640, -0.9712,  0.0790, -0.5852, -0.9922],
#         [-1.0164, -1.6938,  1.6908, -0.2834, -0.8296, -0.4889],
#         [-0.5493,  0.0920, -0.1315,  0.1374,  0.8363,  1.2527],
#         [ 0.1292,  1.5971,  0.8172,  0.0666, -0.8052, -0.4801]])
# tag_space is
# tensor([[-0.1663,  0.1064, -0.2628],
#         [-0.1388,  0.0170, -0.3017],
#         [-0.1074, -0.0396, -0.2060],
#         [-0.2053,  0.0895, -0.2832],
#         [-0.3295, -0.0609, -0.4147]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1698, -0.8972, -1.2664],
#         [-1.1047, -0.9489, -1.2675],
#         [-1.0906, -1.0229, -1.1893],
#         [-1.1842, -0.8894, -1.2620],
#         [-1.1714, -0.9028, -1.2566]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0789992809295654
#
# tag_scores is
#
# tensor([[-1.1698, -0.8972, -1.2664],
#         [-1.1047, -0.9489, -1.2675],
#         [-1.0906, -1.0229, -1.1893],
#         [-1.1842, -0.8894, -1.2620],
#         [-1.1714, -0.9028, -1.2566]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0786, -1.5454,  1.4803,  0.0642,  0.7961,  0.1589],
#         [ 0.1913, -0.8492, -0.2629, -0.9772,  0.3940, -0.3932],
#         [ 0.8962,  0.1172, -1.6509, -0.5693, -0.6039,  0.4472],
#         [ 1.2284, -0.4079,  0.9067, -0.2979, -0.3660, -0.4599]])
# tag_space is
# tensor([[-0.1396,  0.0687, -0.2197],
#         [-0.1589,  0.1155, -0.3562],
#         [-0.1631,  0.0977, -0.4722],
#         [-0.2199,  0.0137, -0.4567]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1489, -0.9405, -1.2289],
#         [-1.1431, -0.8688, -1.3404],
#         [-1.1093, -0.8484, -1.4183],
#         [-1.1159, -0.8823, -1.3527]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.068129062652588
#
# tag_scores is
#
# tensor([[-1.1489, -0.9405, -1.2289],
#         [-1.1431, -0.8688, -1.3404],
#         [-1.1093, -0.8484, -1.4183],
#         [-1.1159, -0.8823, -1.3527]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2577, -1.1945,  0.1849,  0.9679,  0.7878,  0.7887],
#         [-1.0260, -2.1640, -0.9715,  0.0787, -0.5848, -0.9925],
#         [-1.0165, -1.6939,  1.6914, -0.2829, -0.8298, -0.4890],
#         [-0.5491,  0.0913, -0.1317,  0.1368,  0.8356,  1.2528],
#         [ 0.1295,  1.5974,  0.8166,  0.0662, -0.8044, -0.4799]])
# tag_space is
# tensor([[-0.1649,  0.1156, -0.2741],
#         [-0.1382,  0.0274, -0.3122],
#         [-0.1083, -0.0282, -0.2160],
#         [-0.2030,  0.0986, -0.2941],
#         [-0.3297, -0.0460, -0.4292]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1695, -0.8890, -1.2787],
#         [-1.1054, -0.9398, -1.2794],
#         [-1.0924, -1.0122, -1.2000],
#         [-1.1832, -0.8817, -1.2744],
#         [-1.1735, -0.8898, -1.2730]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0764652490615845
#
# tag_scores is
#
# tensor([[-1.1695, -0.8890, -1.2787],
#         [-1.1054, -0.9398, -1.2794],
#         [-1.0924, -1.0122, -1.2000],
#         [-1.1832, -0.8817, -1.2744],
#         [-1.1735, -0.8898, -1.2730]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0785, -1.5444,  1.4794,  0.0638,  0.7970,  0.1589],
#         [ 0.1907, -0.8497, -0.2621, -0.9769,  0.3934, -0.3932],
#         [ 0.8961,  0.1168, -1.6513, -0.5698, -0.6049,  0.4473],
#         [ 1.2284, -0.4068,  0.9057, -0.2982, -0.3647, -0.4598]])
# tag_space is
# tensor([[-0.1407,  0.0800, -0.2317],
#         [-0.1579,  0.1248, -0.3673],
#         [-0.1606,  0.1062, -0.4834],
#         [-0.2209,  0.0272, -0.4710]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1505, -0.9299, -1.2416],
#         [-1.1435, -0.8608, -1.3529],
#         [-1.1085, -0.8417, -1.4314],
#         [-1.1185, -0.8704, -1.3686]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0654228925704956
#
# tag_scores is
#
# tensor([[-1.1505, -0.9299, -1.2416],
#         [-1.1435, -0.8608, -1.3529],
#         [-1.1085, -0.8417, -1.4314],
#         [-1.1185, -0.8704, -1.3686]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2579, -1.1952,  0.1848,  0.9676,  0.7872,  0.7889],
#         [-1.0259, -2.1640, -0.9717,  0.0785, -0.5844, -0.9927],
#         [-1.0166, -1.6939,  1.6919, -0.2824, -0.8299, -0.4891],
#         [-0.5489,  0.0907, -0.1319,  0.1363,  0.8348,  1.2529],
#         [ 0.1299,  1.5977,  0.8161,  0.0658, -0.8036, -0.4797]])
# tag_space is
# tensor([[-0.1635,  0.1240, -0.2846],
#         [-0.1375,  0.0368, -0.3220],
#         [-0.1092, -0.0177, -0.2251],
#         [-0.2005,  0.1068, -0.3043],
#         [-0.3299, -0.0320, -0.4428]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1690, -0.8816, -1.2902],
#         [-1.1059, -0.9316, -1.2904],
#         [-1.0940, -1.0026, -1.2099],
#         [-1.1821, -0.8748, -1.2859],
#         [-1.1756, -0.8778, -1.2886]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0740910768508911
#
# tag_scores is
#
# tensor([[-1.1690, -0.8816, -1.2902],
#         [-1.1059, -0.9316, -1.2904],
#         [-1.0940, -1.0026, -1.2099],
#         [-1.1821, -0.8748, -1.2859],
#         [-1.1756, -0.8778, -1.2886]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0784, -1.5434,  1.4785,  0.0635,  0.7979,  0.1590],
#         [ 0.1901, -0.8503, -0.2613, -0.9767,  0.3928, -0.3932],
#         [ 0.8960,  0.1164, -1.6518, -0.5702, -0.6059,  0.4473],
#         [ 1.2285, -0.4056,  0.9047, -0.2984, -0.3635, -0.4598]])
# tag_space is
# tensor([[-0.1415,  0.0904, -0.2430],
#         [-0.1569,  0.1333, -0.3776],
#         [-0.1581,  0.1138, -0.4940],
#         [-0.2217,  0.0397, -0.4844]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1520, -0.9201, -1.2535],
#         [-1.1438, -0.8536, -1.3645],
#         [-1.1076, -0.8357, -1.4435],
#         [-1.1209, -0.8595, -1.3837]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0629233121871948
#
# tag_scores is
#
# tensor([[-1.1520, -0.9201, -1.2535],
#         [-1.1438, -0.8536, -1.3645],
#         [-1.1076, -0.8357, -1.4435],
#         [-1.1209, -0.8595, -1.3837]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2580, -1.1958,  0.1846,  0.9674,  0.7865,  0.7891],
#         [-1.0257, -2.1639, -0.9719,  0.0782, -0.5840, -0.9930],
#         [-1.0168, -1.6940,  1.6925, -0.2818, -0.8300, -0.4892],
#         [-0.5487,  0.0900, -0.1321,  0.1357,  0.8341,  1.2530],
#         [ 0.1302,  1.5981,  0.8157,  0.0655, -0.8029, -0.4796]])
# tag_space is
# tensor([[-0.1619,  0.1316, -0.2945],
#         [-0.1367,  0.0453, -0.3310],
#         [-0.1099, -0.0082, -0.2334],
#         [-0.1981,  0.1142, -0.3137],
#         [-0.3300, -0.0189, -0.4557]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1684, -0.8749, -1.3010],
#         [-1.1063, -0.9243, -1.3005],
#         [-1.0955, -0.9939, -1.2191],
#         [-1.1809, -0.8687, -1.2965],
#         [-1.1777, -0.8666, -1.3033]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.071852684020996
#
# tag_scores is
#
# tensor([[-1.1684, -0.8749, -1.3010],
#         [-1.1063, -0.9243, -1.3005],
#         [-1.0955, -0.9939, -1.2191],
#         [-1.1809, -0.8687, -1.2965],
#         [-1.1777, -0.8666, -1.3033]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0783, -1.5425,  1.4777,  0.0632,  0.7988,  0.1590],
#         [ 0.1894, -0.8508, -0.2605, -0.9764,  0.3922, -0.3932],
#         [ 0.8960,  0.1160, -1.6522, -0.5706, -0.6068,  0.4474],
#         [ 1.2285, -0.4044,  0.9037, -0.2987, -0.3623, -0.4598]])
# tag_space is
# tensor([[-0.1423,  0.1000, -0.2536],
#         [-0.1557,  0.1411, -0.3872],
#         [-0.1555,  0.1207, -0.5038],
#         [-0.2224,  0.0514, -0.4972]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1534, -0.9111, -1.2647],
#         [-1.1438, -0.8471, -1.3754],
#         [-1.1066, -0.8304, -1.4549],
#         [-1.1232, -0.8494, -1.3980]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.060603141784668
#
# tag_scores is
#
# tensor([[-1.1534, -0.9111, -1.2647],
#         [-1.1438, -0.8471, -1.3754],
#         [-1.1066, -0.8304, -1.4549],
#         [-1.1232, -0.8494, -1.3980]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2581, -1.1964,  0.1845,  0.9672,  0.7858,  0.7893],
#         [-1.0256, -2.1639, -0.9721,  0.0780, -0.5836, -0.9933],
#         [-1.0169, -1.6941,  1.6931, -0.2813, -0.8301, -0.4893],
#         [-0.5486,  0.0894, -0.1323,  0.1352,  0.8334,  1.2532],
#         [ 0.1306,  1.5984,  0.8152,  0.0651, -0.8021, -0.4795]])
# tag_space is
# tensor([[-0.1603,  0.1385, -0.3036],
#         [-0.1358,  0.0530, -0.3392],
#         [-0.1104,  0.0005, -0.2409],
#         [-0.1955,  0.1209, -0.3223],
#         [-0.3301, -0.0066, -0.4678]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1677, -0.8690, -1.3110],
#         [-1.1065, -0.9177, -1.3099],
#         [-1.0969, -0.9860, -1.2274],
#         [-1.1796, -0.8632, -1.3064],
#         [-1.1796, -0.8562, -1.3174]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0697295665740967
#
# tag_scores is
#
# tensor([[-1.1677, -0.8690, -1.3110],
#         [-1.1065, -0.9177, -1.3099],
#         [-1.0969, -0.9860, -1.2274],
#         [-1.1796, -0.8632, -1.3064],
#         [-1.1796, -0.8562, -1.3174]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5415,  1.4768,  0.0629,  0.7997,  0.1590],
#         [ 0.1887, -0.8514, -0.2598, -0.9761,  0.3916, -0.3931],
#         [ 0.8959,  0.1156, -1.6527, -0.5710, -0.6077,  0.4475],
#         [ 1.2287, -0.4032,  0.9028, -0.2988, -0.3611, -0.4599]])
# tag_space is
# tensor([[-0.1429,  0.1088, -0.2635],
#         [-0.1545,  0.1481, -0.3962],
#         [-0.1528,  0.1269, -0.5130],
#         [-0.2229,  0.0624, -0.5092]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1545, -0.9028, -1.2752],
#         [-1.1438, -0.8412, -1.3855],
#         [-1.1054, -0.8256, -1.4655],
#         [-1.1253, -0.8400, -1.4116]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0584380626678467
#
# tag_scores is
#
# tensor([[-1.1545, -0.9028, -1.2752],
#         [-1.1438, -0.8412, -1.3855],
#         [-1.1054, -0.8256, -1.4655],
#         [-1.1253, -0.8400, -1.4116]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2581, -1.1970,  0.1844,  0.9670,  0.7852,  0.7894],
#         [-1.0254, -2.1639, -0.9722,  0.0778, -0.5832, -0.9936],
#         [-1.0171, -1.6942,  1.6937, -0.2808, -0.8302, -0.4893],
#         [-0.5484,  0.0887, -0.1325,  0.1346,  0.8327,  1.2533],
#         [ 0.1309,  1.5987,  0.8147,  0.0648, -0.8015, -0.4794]])
# tag_space is
# tensor([[-0.1587,  0.1447, -0.3121],
#         [-0.1349,  0.0600, -0.3468],
#         [-0.1109,  0.0085, -0.2477],
#         [-0.1930,  0.1268, -0.3303],
#         [-0.3301,  0.0049, -0.4793]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1669, -0.8636, -1.3204],
#         [-1.1066, -0.9117, -1.3186],
#         [-1.0982, -0.9789, -1.2351],
#         [-1.1782, -0.8584, -1.3155],
#         [-1.1815, -0.8465, -1.3307]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.067704439163208
#
# tag_scores is
#
# tensor([[-1.1669, -0.8636, -1.3204],
#         [-1.1066, -0.9117, -1.3186],
#         [-1.0982, -0.9789, -1.2351],
#         [-1.1782, -0.8584, -1.3155],
#         [-1.1815, -0.8465, -1.3307]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5405,  1.4761,  0.0626,  0.8005,  0.1590],
#         [ 0.1880, -0.8521, -0.2590, -0.9758,  0.3910, -0.3930],
#         [ 0.8958,  0.1152, -1.6531, -0.5714, -0.6086,  0.4476],
#         [ 1.2288, -0.4021,  0.9019, -0.2990, -0.3599, -0.4600]])
# tag_space is
# tensor([[-0.1434,  0.1169, -0.2729],
#         [-0.1532,  0.1545, -0.4046],
#         [-0.1502,  0.1325, -0.5215],
#         [-0.2234,  0.0726, -0.5207]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1556, -0.8952, -1.2851],
#         [-1.1435, -0.8359, -1.3950],
#         [-1.1041, -0.8214, -1.4754],
#         [-1.1273, -0.8313, -1.4246]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0564074516296387
#
# tag_scores is
#
# tensor([[-1.1556, -0.8952, -1.2851],
#         [-1.1435, -0.8359, -1.3950],
#         [-1.1041, -0.8214, -1.4754],
#         [-1.1273, -0.8313, -1.4246]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2582, -1.1977,  0.1843,  0.9667,  0.7846,  0.7896],
#         [-1.0253, -2.1638, -0.9724,  0.0776, -0.5829, -0.9939],
#         [-1.0172, -1.6943,  1.6942, -0.2803, -0.8303, -0.4894],
#         [-0.5482,  0.0881, -0.1327,  0.1341,  0.8320,  1.2534],
#         [ 0.1313,  1.5991,  0.8143,  0.0645, -0.8008, -0.4793]])
# tag_space is
# tensor([[-0.1570,  0.1503, -0.3201],
#         [-0.1339,  0.0663, -0.3538],
#         [-0.1112,  0.0157, -0.2539],
#         [-0.1904,  0.1322, -0.3377],
#         [-0.3301,  0.0158, -0.4901]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1660, -0.8588, -1.3291],
#         [-1.1067, -0.9065, -1.3266],
#         [-1.0994, -0.9725, -1.2421],
#         [-1.1768, -0.8541, -1.3240],
#         [-1.1834, -0.8375, -1.3434]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0657622814178467
#
# tag_scores is
#
# tensor([[-1.1660, -0.8588, -1.3291],
#         [-1.1067, -0.9065, -1.3266],
#         [-1.0994, -0.9725, -1.2421],
#         [-1.1768, -0.8541, -1.3240],
#         [-1.1834, -0.8375, -1.3434]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5396,  1.4753,  0.0624,  0.8013,  0.1590],
#         [ 0.1873, -0.8527, -0.2582, -0.9756,  0.3904, -0.3930],
#         [ 0.8957,  0.1148, -1.6536, -0.5718, -0.6095,  0.4477],
#         [ 1.2290, -0.4009,  0.9011, -0.2992, -0.3588, -0.4601]])
# tag_space is
# tensor([[-0.1438,  0.1244, -0.2818],
#         [-0.1518,  0.1602, -0.4124],
#         [-0.1475,  0.1375, -0.5295],
#         [-0.2238,  0.0821, -0.5315]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1565, -0.8883, -1.2944],
#         [-1.1432, -0.8311, -1.4038],
#         [-1.1027, -0.8177, -1.4847],
#         [-1.1291, -0.8232, -1.4369]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0544931888580322
#
# tag_scores is
#
# tensor([[-1.1565, -0.8883, -1.2944],
#         [-1.1432, -0.8311, -1.4038],
#         [-1.1027, -0.8177, -1.4847],
#         [-1.1291, -0.8232, -1.4369]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2583, -1.1983,  0.1841,  0.9665,  0.7840,  0.7898],
#         [-1.0251, -2.1638, -0.9725,  0.0775, -0.5826, -0.9942],
#         [-1.0174, -1.6944,  1.6948, -0.2797, -0.8304, -0.4894],
#         [-0.5481,  0.0874, -0.1330,  0.1336,  0.8313,  1.2536],
#         [ 0.1317,  1.5994,  0.8139,  0.0642, -0.8001, -0.4792]])
# tag_space is
# tensor([[-0.1552,  0.1553, -0.3275],
#         [-0.1329,  0.0720, -0.3602],
#         [-0.1115,  0.0223, -0.2595],
#         [-0.1878,  0.1370, -0.3444],
#         [-0.3300,  0.0261, -0.5004]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1650, -0.8544, -1.3373],
#         [-1.1066, -0.9017, -1.3339],
#         [-1.1005, -0.9667, -1.2485],
#         [-1.1752, -0.8504, -1.3318],
#         [-1.1852, -0.8290, -1.3555]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0638902187347412
#
# tag_scores is
#
# tensor([[-1.1650, -0.8544, -1.3373],
#         [-1.1066, -0.9017, -1.3339],
#         [-1.1005, -0.9667, -1.2485],
#         [-1.1752, -0.8504, -1.3318],
#         [-1.1852, -0.8290, -1.3555]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5386,  1.4746,  0.0621,  0.8022,  0.1589],
#         [ 0.1865, -0.8534, -0.2575, -0.9753,  0.3898, -0.3928],
#         [ 0.8956,  0.1144, -1.6541, -0.5722, -0.6103,  0.4478],
#         [ 1.2292, -0.3997,  0.9003, -0.2993, -0.3576, -0.4602]])
# tag_space is
# tensor([[-0.1442,  0.1313, -0.2901],
#         [-0.1504,  0.1655, -0.4197],
#         [-0.1448,  0.1420, -0.5370],
#         [-0.2241,  0.0911, -0.5419]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1574, -0.8818, -1.3032],
#         [-1.1428, -0.8269, -1.4121],
#         [-1.1012, -0.8144, -1.4934],
#         [-1.1308, -0.8157, -1.4486]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0526795387268066
#
# tag_scores is
#
# tensor([[-1.1574, -0.8818, -1.3032],
#         [-1.1428, -0.8269, -1.4121],
#         [-1.1012, -0.8144, -1.4934],
#         [-1.1308, -0.8157, -1.4486]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2583, -1.1989,  0.1839,  0.9663,  0.7834,  0.7900],
#         [-1.0250, -2.1637, -0.9726,  0.0773, -0.5823, -0.9945],
#         [-1.0176, -1.6946,  1.6954, -0.2792, -0.8305, -0.4895],
#         [-0.5479,  0.0868, -0.1332,  0.1331,  0.8306,  1.2537],
#         [ 0.1321,  1.5998,  0.8135,  0.0640, -0.7995, -0.4792]])
# tag_space is
# tensor([[-0.1535,  0.1599, -0.3345],
#         [-0.1318,  0.0771, -0.3661],
#         [-0.1116,  0.0283, -0.2645],
#         [-0.1852,  0.1412, -0.3507],
#         [-0.3300,  0.0358, -0.5101]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1639, -0.8506, -1.3449],
#         [-1.1064, -0.8975, -1.3407],
#         [-1.1014, -0.9615, -1.2543],
#         [-1.1736, -0.8472, -1.3390],
#         [-1.1869, -0.8211, -1.3670]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0620777606964111
#
# tag_scores is
#
# tensor([[-1.1639, -0.8506, -1.3449],
#         [-1.1064, -0.8975, -1.3407],
#         [-1.1014, -0.9615, -1.2543],
#         [-1.1736, -0.8472, -1.3390],
#         [-1.1869, -0.8211, -1.3670]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5377,  1.4739,  0.0619,  0.8030,  0.1588],
#         [ 0.1857, -0.8541, -0.2568, -0.9751,  0.3892, -0.3927],
#         [ 0.8955,  0.1140, -1.6546, -0.5726, -0.6112,  0.4479],
#         [ 1.2294, -0.3985,  0.8996, -0.2994, -0.3565, -0.4604]])
# tag_space is
# tensor([[-0.1445,  0.1377, -0.2980],
#         [-0.1490,  0.1702, -0.4265],
#         [-0.1421,  0.1460, -0.5440],
#         [-0.2243,  0.0995, -0.5517]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1581, -0.8759, -1.3115],
#         [-1.1422, -0.8230, -1.4198],
#         [-1.0996, -0.8115, -1.5015],
#         [-1.1325, -0.8086, -1.4598]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0509519577026367
#
# tag_scores is
#
# tensor([[-1.1581, -0.8759, -1.3115],
#         [-1.1422, -0.8230, -1.4198],
#         [-1.0996, -0.8115, -1.5015],
#         [-1.1325, -0.8086, -1.4598]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.1995,  0.1838,  0.9661,  0.7828,  0.7903],
#         [-1.0248, -2.1636, -0.9727,  0.0772, -0.5820, -0.9949],
#         [-1.0178, -1.6948,  1.6960, -0.2787, -0.8305, -0.4895],
#         [-0.5478,  0.0861, -0.1335,  0.1325,  0.8299,  1.2539],
#         [ 0.1325,  1.6001,  0.8131,  0.0637, -0.7989, -0.4792]])
# tag_space is
# tensor([[-0.1517,  0.1639, -0.3410],
#         [-0.1307,  0.0817, -0.3714],
#         [-0.1117,  0.0338, -0.2690],
#         [-0.1826,  0.1449, -0.3564],
#         [-0.3299,  0.0450, -0.5192]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1627, -0.8471, -1.3520],
#         [-1.1061, -0.8938, -1.3469],
#         [-1.1023, -0.9568, -1.2596],
#         [-1.1719, -0.8443, -1.3457],
#         [-1.1886, -0.8136, -1.3779]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0603151321411133
#
# tag_scores is
#
# tensor([[-1.1627, -0.8471, -1.3520],
#         [-1.1061, -0.8938, -1.3469],
#         [-1.1023, -0.9568, -1.2596],
#         [-1.1719, -0.8443, -1.3457],
#         [-1.1886, -0.8136, -1.3779]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0782, -1.5367,  1.4732,  0.0617,  0.8038,  0.1587],
#         [ 0.1849, -0.8548, -0.2561, -0.9749,  0.3886, -0.3925],
#         [ 0.8954,  0.1136, -1.6551, -0.5730, -0.6120,  0.4481],
#         [ 1.2296, -0.3974,  0.8989, -0.2995, -0.3555, -0.4605]])
# tag_space is
# tensor([[-0.1447,  0.1436, -0.3054],
#         [-0.1475,  0.1745, -0.4329],
#         [-0.1393,  0.1496, -0.5506],
#         [-0.2245,  0.1074, -0.5611]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1587, -0.8704, -1.3194],
#         [-1.1416, -0.8195, -1.4269],
#         [-1.0979, -0.8089, -1.5091],
#         [-1.1340, -0.8020, -1.4705]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0492985248565674
#
# tag_scores is
#
# tensor([[-1.1587, -0.8704, -1.3194],
#         [-1.1416, -0.8195, -1.4269],
#         [-1.0979, -0.8089, -1.5091],
#         [-1.1340, -0.8020, -1.4705]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2001,  0.1836,  0.9659,  0.7822,  0.7905],
#         [-1.0247, -2.1636, -0.9728,  0.0771, -0.5817, -0.9952],
#         [-1.0181, -1.6949,  1.6966, -0.2782, -0.8306, -0.4895],
#         [-0.5476,  0.0855, -0.1338,  0.1320,  0.8292,  1.2540],
#         [ 0.1329,  1.6005,  0.8128,  0.0635, -0.7983, -0.4792]])
# tag_space is
# tensor([[-0.1499,  0.1675, -0.3470],
#         [-0.1295,  0.0858, -0.3763],
#         [-0.1117,  0.0387, -0.2729],
#         [-0.1800,  0.1482, -0.3616],
#         [-0.3298,  0.0538, -0.5280]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1615, -0.8441, -1.3586],
#         [-1.1058, -0.8905, -1.3526],
#         [-1.1031, -0.9527, -1.2643],
#         [-1.1701, -0.8419, -1.3518],
#         [-1.1902, -0.8066, -1.3883]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0585947036743164
#
# tag_scores is
#
# tensor([[-1.1615, -0.8441, -1.3586],
#         [-1.1058, -0.8905, -1.3526],
#         [-1.1031, -0.9527, -1.2643],
#         [-1.1701, -0.8419, -1.3518],
#         [-1.1902, -0.8066, -1.3883]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0783, -1.5358,  1.4726,  0.0615,  0.8046,  0.1586],
#         [ 0.1841, -0.8555, -0.2554, -0.9747,  0.3881, -0.3924],
#         [ 0.8954,  0.1132, -1.6557, -0.5734, -0.6128,  0.4482],
#         [ 1.2299, -0.3962,  0.8982, -0.2995, -0.3544, -0.4607]])
# tag_space is
# tensor([[-0.1449,  0.1490, -0.3124],
#         [-0.1460,  0.1784, -0.4388],
#         [-0.1366,  0.1528, -0.5567],
#         [-0.2247,  0.1149, -0.5700]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1593, -0.8653, -1.3267],
#         [-1.1408, -0.8164, -1.4336],
#         [-1.0961, -0.8067, -1.5162],
#         [-1.1354, -0.7958, -1.4807]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.04770827293396
#
# tag_scores is
#
# tensor([[-1.1593, -0.8653, -1.3267],
#         [-1.1408, -0.8164, -1.4336],
#         [-1.0961, -0.8067, -1.5162],
#         [-1.1354, -0.7958, -1.4807]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2007,  0.1834,  0.9658,  0.7816,  0.7907],
#         [-1.0245, -2.1635, -0.9729,  0.0770, -0.5814, -0.9956],
#         [-1.0183, -1.6951,  1.6973, -0.2776, -0.8307, -0.4895],
#         [-0.5475,  0.0848, -0.1341,  0.1315,  0.8285,  1.2542],
#         [ 0.1333,  1.6009,  0.8124,  0.0633, -0.7977, -0.4792]])
# tag_space is
# tensor([[-0.1481,  0.1708, -0.3527],
#         [-0.1284,  0.0894, -0.3808],
#         [-0.1116,  0.0432, -0.2764],
#         [-0.1773,  0.1510, -0.3664],
#         [-0.3298,  0.0621, -0.5362]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1602, -0.8413, -1.3648],
#         [-1.1053, -0.8876, -1.3577],
#         [-1.1038, -0.9490, -1.2685],
#         [-1.1682, -0.8399, -1.3574],
#         [-1.1918, -0.8000, -1.3983]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0569089651107788
#
# tag_scores is
#
# tensor([[-1.1602, -0.8413, -1.3648],
#         [-1.1053, -0.8876, -1.3577],
#         [-1.1038, -0.9490, -1.2685],
#         [-1.1682, -0.8399, -1.3574],
#         [-1.1918, -0.8000, -1.3983]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0783, -1.5348,  1.4720,  0.0613,  0.8054,  0.1584],
#         [ 0.1833, -0.8563, -0.2547, -0.9744,  0.3875, -0.3922],
#         [ 0.8953,  0.1128, -1.6562, -0.5738, -0.6136,  0.4484],
#         [ 1.2302, -0.3950,  0.8975, -0.2996, -0.3534, -0.4610]])
# tag_space is
# tensor([[-0.1451,  0.1541, -0.3191],
#         [-0.1445,  0.1818, -0.4444],
#         [-0.1338,  0.1556, -0.5624],
#         [-0.2249,  0.1220, -0.5786]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1597, -0.8605, -1.3337],
#         [-1.1400, -0.8137, -1.4399],
#         [-1.0943, -0.8049, -1.5229],
#         [-1.1368, -0.7899, -1.4905]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0461715459823608
#
# tag_scores is
#
# tensor([[-1.1597, -0.8605, -1.3337],
#         [-1.1400, -0.8137, -1.4399],
#         [-1.0943, -0.8049, -1.5229],
#         [-1.1368, -0.7899, -1.4905]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2012,  0.1832,  0.9656,  0.7811,  0.7909],
#         [-1.0244, -2.1634, -0.9730,  0.0769, -0.5812, -0.9960],
#         [-1.0186, -1.6954,  1.6979, -0.2771, -0.8307, -0.4895],
#         [-0.5474,  0.0841, -0.1344,  0.1310,  0.8278,  1.2543],
#         [ 0.1337,  1.6012,  0.8121,  0.0631, -0.7971, -0.4792]])
# tag_space is
# tensor([[-0.1463,  0.1736, -0.3580],
#         [-0.1272,  0.0926, -0.3848],
#         [-0.1115,  0.0472, -0.2794],
#         [-0.1746,  0.1535, -0.3708],
#         [-0.3297,  0.0700, -0.5441]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1588, -0.8389, -1.3705],
#         [-1.1048, -0.8850, -1.3625],
#         [-1.1044, -0.9457, -1.2723],
#         [-1.1664, -0.8382, -1.3625],
#         [-1.1934, -0.7937, -1.4078]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.055252194404602
#
# tag_scores is
#
# tensor([[-1.1588, -0.8389, -1.3705],
#         [-1.1048, -0.8850, -1.3625],
#         [-1.1044, -0.9457, -1.2723],
#         [-1.1664, -0.8382, -1.3625],
#         [-1.1934, -0.7937, -1.4078]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0784, -1.5339,  1.4714,  0.0611,  0.8062,  0.1583],
#         [ 0.1824, -0.8571, -0.2540, -0.9742,  0.3870, -0.3919],
#         [ 0.8952,  0.1124, -1.6568, -0.5742, -0.6144,  0.4485],
#         [ 1.2305, -0.3938,  0.8969, -0.2996, -0.3523, -0.4612]])
# tag_space is
# tensor([[-0.1453,  0.1587, -0.3254],
#         [-0.1430,  0.1850, -0.4496],
#         [-0.1311,  0.1581, -0.5678],
#         [-0.2250,  0.1286, -0.5868]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1601, -0.8562, -1.3403],
#         [-1.1392, -0.8112, -1.4457],
#         [-1.0924, -0.8032, -1.5291],
#         [-1.1380, -0.7844, -1.4998]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0446797609329224
#
# tag_scores is
#
# tensor([[-1.1601, -0.8562, -1.3403],
#         [-1.1392, -0.8112, -1.4457],
#         [-1.0924, -0.8032, -1.5291],
#         [-1.1380, -0.7844, -1.4998]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2018,  0.1830,  0.9654,  0.7805,  0.7912],
#         [-1.0243, -2.1634, -0.9731,  0.0769, -0.5809, -0.9964],
#         [-1.0189, -1.6956,  1.6985, -0.2766, -0.8308, -0.4895],
#         [-0.5472,  0.0835, -0.1347,  0.1305,  0.8271,  1.2545],
#         [ 0.1341,  1.6016,  0.8118,  0.0629, -0.7966, -0.4793]])
# tag_space is
# tensor([[-0.1445,  0.1761, -0.3630],
#         [-0.1260,  0.0955, -0.3885],
#         [-0.1114,  0.0509, -0.2820],
#         [-0.1720,  0.1556, -0.3748],
#         [-0.3297,  0.0775, -0.5516]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1574, -0.8368, -1.3759],
#         [-1.1043, -0.8828, -1.3668],
#         [-1.1050, -0.9428, -1.2757],
#         [-1.1644, -0.8368, -1.3672],
#         [-1.1950, -0.7878, -1.4169]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0536187887191772
#
# tag_scores is
#
# tensor([[-1.1574, -0.8368, -1.3759],
#         [-1.1043, -0.8828, -1.3668],
#         [-1.1050, -0.9428, -1.2757],
#         [-1.1644, -0.8368, -1.3672],
#         [-1.1950, -0.7878, -1.4169]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0785, -1.5329,  1.4708,  0.0609,  0.8069,  0.1581],
#         [ 0.1815, -0.8579, -0.2533, -0.9740,  0.3865, -0.3917],
#         [ 0.8951,  0.1120, -1.6573, -0.5746, -0.6151,  0.4487],
#         [ 1.2309, -0.3926,  0.8964, -0.2996, -0.3513, -0.4615]])
# tag_space is
# tensor([[-0.1454,  0.1630, -0.3314],
#         [-0.1415,  0.1878, -0.4544],
#         [-0.1283,  0.1603, -0.5728],
#         [-0.2251,  0.1350, -0.5946]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1605, -0.8521, -1.3465],
#         [-1.1382, -0.8090, -1.4511],
#         [-1.0905, -0.8019, -1.5350],
#         [-1.1393, -0.7792, -1.5088]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0432252883911133
#
# tag_scores is
#
# tensor([[-1.1605, -0.8521, -1.3465],
#         [-1.1382, -0.8090, -1.4511],
#         [-1.0905, -0.8019, -1.5350],
#         [-1.1393, -0.7792, -1.5088]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2024,  0.1828,  0.9652,  0.7800,  0.7914],
#         [-1.0241, -2.1633, -0.9731,  0.0768, -0.5807, -0.9968],
#         [-1.0192, -1.6959,  1.6991, -0.2761, -0.8309, -0.4895],
#         [-0.5471,  0.0828, -0.1351,  0.1300,  0.8265,  1.2547],
#         [ 0.1345,  1.6020,  0.8115,  0.0627, -0.7961, -0.4794]])
# tag_space is
# tensor([[-0.1427,  0.1784, -0.3676],
#         [-0.1248,  0.0980, -0.3918],
#         [-0.1111,  0.0541, -0.2842],
#         [-0.1693,  0.1574, -0.3784],
#         [-0.3297,  0.0848, -0.5587]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1560, -0.8349, -1.3809],
#         [-1.1037, -0.8809, -1.3707],
#         [-1.1055, -0.9403, -1.2786],
#         [-1.1624, -0.8357, -1.3715],
#         [-1.1966, -0.7821, -1.4256]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0520042181015015
#
# tag_scores is
#
# tensor([[-1.1560, -0.8349, -1.3809],
#         [-1.1037, -0.8809, -1.3707],
#         [-1.1055, -0.9403, -1.2786],
#         [-1.1624, -0.8357, -1.3715],
#         [-1.1966, -0.7821, -1.4256]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0786, -1.5320,  1.4702,  0.0608,  0.8077,  0.1579],
#         [ 0.1806, -0.8587, -0.2527, -0.9738,  0.3859, -0.3914],
#         [ 0.8950,  0.1116, -1.6579, -0.5750, -0.6159,  0.4489],
#         [ 1.2313, -0.3914,  0.8958, -0.2996, -0.3503, -0.4618]])
# tag_space is
# tensor([[-0.1455,  0.1670, -0.3371],
#         [-0.1399,  0.1903, -0.4589],
#         [-0.1255,  0.1622, -0.5775],
#         [-0.2252,  0.1410, -0.6022]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1608, -0.8483, -1.3524],
#         [-1.1373, -0.8070, -1.4562],
#         [-1.0885, -0.8007, -1.5405],
#         [-1.1405, -0.7742, -1.5175]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0418009757995605
#
# tag_scores is
#
# tensor([[-1.1608, -0.8483, -1.3524],
#         [-1.1373, -0.8070, -1.4562],
#         [-1.0885, -0.8007, -1.5405],
#         [-1.1405, -0.7742, -1.5175]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2584, -1.2030,  0.1826,  0.9650,  0.7795,  0.7917],
#         [-1.0240, -2.1632, -0.9732,  0.0768, -0.5805, -0.9972],
#         [-1.0195, -1.6961,  1.6998, -0.2756, -0.8309, -0.4894],
#         [-0.5470,  0.0821, -0.1354,  0.1295,  0.8258,  1.2549],
#         [ 0.1349,  1.6024,  0.8112,  0.0626, -0.7956, -0.4795]])
# tag_space is
# tensor([[-0.1409,  0.1803, -0.3720],
#         [-0.1235,  0.1002, -0.3947],
#         [-0.1109,  0.0570, -0.2860],
#         [-0.1666,  0.1588, -0.3816],
#         [-0.3297,  0.0917, -0.5655]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1545, -0.8333, -1.3856],
#         [-1.1030, -0.8793, -1.3742],
#         [-1.1060, -0.9381, -1.2811],
#         [-1.1604, -0.8349, -1.3754],
#         [-1.1982, -0.7768, -1.4340]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0504043102264404
#
# tag_scores is
#
# tensor([[-1.1545, -0.8333, -1.3856],
#         [-1.1030, -0.8793, -1.3742],
#         [-1.1060, -0.9381, -1.2811],
#         [-1.1604, -0.8349, -1.3754],
#         [-1.1982, -0.7768, -1.4340]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0787, -1.5310,  1.4697,  0.0607,  0.8085,  0.1577],
#         [ 0.1797, -0.8595, -0.2520, -0.9737,  0.3854, -0.3911],
#         [ 0.8949,  0.1113, -1.6585, -0.5754, -0.6166,  0.4491],
#         [ 1.2317, -0.3901,  0.8954, -0.2996, -0.3494, -0.4621]])
# tag_space is
# tensor([[-0.1456,  0.1708, -0.3425],
#         [-0.1384,  0.1925, -0.4631],
#         [-0.1228,  0.1638, -0.5820],
#         [-0.2253,  0.1468, -0.6095]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1611, -0.8447, -1.3580],
#         [-1.1362, -0.8053, -1.4609],
#         [-1.0864, -0.7998, -1.5456],
#         [-1.1416, -0.7695, -1.5258]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0404008626937866
#
# tag_scores is
#
# tensor([[-1.1611, -0.8447, -1.3580],
#         [-1.1362, -0.8053, -1.4609],
#         [-1.0864, -0.7998, -1.5456],
#         [-1.1416, -0.7695, -1.5258]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2583, -1.2036,  0.1823,  0.9648,  0.7790,  0.7919],
#         [-1.0238, -2.1631, -0.9732,  0.0768, -0.5803, -0.9976],
#         [-1.0199, -1.6964,  1.7004, -0.2751, -0.8310, -0.4894],
#         [-0.5469,  0.0815, -0.1358,  0.1290,  0.8252,  1.2551],
#         [ 0.1354,  1.6029,  0.8109,  0.0624, -0.7951, -0.4796]])
# tag_space is
# tensor([[-0.1391,  0.1820, -0.3760],
#         [-0.1223,  0.1021, -0.3974],
#         [-0.1106,  0.0596, -0.2875],
#         [-0.1640,  0.1600, -0.3845],
#         [-0.3297,  0.0984, -0.5720]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1530, -0.8319, -1.3899],
#         [-1.1023, -0.8779, -1.3774],
#         [-1.1064, -0.9362, -1.2833],
#         [-1.1583, -0.8344, -1.3789],
#         [-1.1997, -0.7716, -1.4420]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.048815369606018
#
# tag_scores is
#
# tensor([[-1.1530, -0.8319, -1.3899],
#         [-1.1023, -0.8779, -1.3774],
#         [-1.1064, -0.9362, -1.2833],
#         [-1.1583, -0.8344, -1.3789],
#         [-1.1997, -0.7716, -1.4420]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0788, -1.5301,  1.4692,  0.0605,  0.8092,  0.1574],
#         [ 0.1787, -0.8604, -0.2514, -0.9735,  0.3849, -0.3908],
#         [ 0.8948,  0.1109, -1.6591, -0.5758, -0.6173,  0.4493],
#         [ 1.2321, -0.3889,  0.8949, -0.2995, -0.3484, -0.4625]])
# tag_space is
# tensor([[-0.1457,  0.1742, -0.3476],
#         [-0.1369,  0.1945, -0.4670],
#         [-0.1200,  0.1652, -0.5861],
#         [-0.2254,  0.1523, -0.6165]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1613, -0.8414, -1.3633],
#         [-1.1352, -0.8038, -1.4653],
#         [-1.0843, -0.7991, -1.5504],
#         [-1.1427, -0.7650, -1.5338]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.039019227027893
#
# tag_scores is
#
# tensor([[-1.1613, -0.8414, -1.3633],
#         [-1.1352, -0.8038, -1.4653],
#         [-1.0843, -0.7991, -1.5504],
#         [-1.1427, -0.7650, -1.5338]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2583, -1.2042,  0.1821,  0.9646,  0.7785,  0.7922],
#         [-1.0237, -2.1630, -0.9732,  0.0767, -0.5801, -0.9981],
#         [-1.0202, -1.6967,  1.7010, -0.2745, -0.8310, -0.4893],
#         [-0.5468,  0.0808, -0.1362,  0.1285,  0.8245,  1.2553],
#         [ 0.1358,  1.6033,  0.8107,  0.0623, -0.7946, -0.4797]])
# tag_space is
# tensor([[-0.1373,  0.1834, -0.3799],
#         [-0.1211,  0.1037, -0.3997],
#         [-0.1102,  0.0619, -0.2886],
#         [-0.1613,  0.1609, -0.3871],
#         [-0.3298,  0.1048, -0.5782]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1514, -0.8307, -1.3940],
#         [-1.1016, -0.8768, -1.3802],
#         [-1.1067, -0.9346, -1.2851],
#         [-1.1562, -0.8341, -1.3821],
#         [-1.2013, -0.7667, -1.4497]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0472339391708374
#
# tag_scores is
#
# tensor([[-1.1514, -0.8307, -1.3940],
#         [-1.1016, -0.8768, -1.3802],
#         [-1.1067, -0.9346, -1.2851],
#         [-1.1562, -0.8341, -1.3821],
#         [-1.2013, -0.7667, -1.4497]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0790, -1.5291,  1.4688,  0.0604,  0.8100,  0.1571],
#         [ 0.1777, -0.8613, -0.2507, -0.9733,  0.3844, -0.3905],
#         [ 0.8947,  0.1105, -1.6598, -0.5762, -0.6180,  0.4495],
#         [ 1.2325, -0.3877,  0.8945, -0.2994, -0.3475, -0.4628]])
# tag_space is
# tensor([[-0.1458,  0.1775, -0.3525],
#         [-0.1353,  0.1963, -0.4707],
#         [-0.1173,  0.1664, -0.5900],
#         [-0.2256,  0.1576, -0.6232]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1615, -0.8383, -1.3683],
#         [-1.1341, -0.8025, -1.4694],
#         [-1.0822, -0.7986, -1.5550],
#         [-1.1438, -0.7607, -1.5415]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0376508235931396
#
# tag_scores is
#
# tensor([[-1.1615, -0.8383, -1.3683],
#         [-1.1341, -0.8025, -1.4694],
#         [-1.0822, -0.7986, -1.5550],
#         [-1.1438, -0.7607, -1.5415]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2582, -1.2047,  0.1818,  0.9644,  0.7780,  0.7925],
#         [-1.0236, -2.1629, -0.9732,  0.0768, -0.5799, -0.9985],
#         [-1.0206, -1.6971,  1.7017, -0.2740, -0.8311, -0.4893],
#         [-0.5467,  0.0801, -0.1366,  0.1279,  0.8239,  1.2555],
#         [ 0.1363,  1.6037,  0.8104,  0.0622, -0.7941, -0.4799]])
# tag_space is
# tensor([[-0.1355,  0.1846, -0.3834],
#         [-0.1198,  0.1051, -0.4018],
#         [-0.1098,  0.0639, -0.2894],
#         [-0.1586,  0.1615, -0.3894],
#         [-0.3299,  0.1111, -0.5841]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1498, -0.8297, -1.3978],
#         [-1.1008, -0.8759, -1.3827],
#         [-1.1070, -0.9333, -1.2866],
#         [-1.1541, -0.8340, -1.3849],
#         [-1.2029, -0.7619, -1.4571]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0456573963165283
#
# tag_scores is
#
# tensor([[-1.1498, -0.8297, -1.3978],
#         [-1.1008, -0.8759, -1.3827],
#         [-1.1070, -0.9333, -1.2866],
#         [-1.1541, -0.8340, -1.3849],
#         [-1.2029, -0.7619, -1.4571]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0791, -1.5282,  1.4683,  0.0603,  0.8107,  0.1569],
#         [ 0.1767, -0.8623, -0.2501, -0.9732,  0.3839, -0.3902],
#         [ 0.8946,  0.1101, -1.6604, -0.5766, -0.6186,  0.4497],
#         [ 1.2330, -0.3864,  0.8941, -0.2993, -0.3465, -0.4632]])
# tag_space is
# tensor([[-0.1459,  0.1805, -0.3572],
#         [-0.1338,  0.1978, -0.4741],
#         [-0.1145,  0.1673, -0.5937],
#         [-0.2257,  0.1627, -0.6298]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1618, -0.8353, -1.3730],
#         [-1.1330, -0.8013, -1.4732],
#         [-1.0801, -0.7982, -1.5592],
#         [-1.1449, -0.7565, -1.5490]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0362910032272339
#
# tag_scores is
#
# tensor([[-1.1618, -0.8353, -1.3730],
#         [-1.1330, -0.8013, -1.4732],
#         [-1.0801, -0.7982, -1.5592],
#         [-1.1449, -0.7565, -1.5490]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2582, -1.2053,  0.1815,  0.9642,  0.7775,  0.7928],
#         [-1.0234, -2.1628, -0.9732,  0.0768, -0.5797, -0.9990],
#         [-1.0210, -1.6974,  1.7023, -0.2735, -0.8311, -0.4892],
#         [-0.5466,  0.0794, -0.1370,  0.1274,  0.8232,  1.2557],
#         [ 0.1367,  1.6042,  0.8102,  0.0621, -0.7937, -0.4800]])
# tag_space is
# tensor([[-0.1337,  0.1856, -0.3868],
#         [-0.1186,  0.1062, -0.4036],
#         [-0.1094,  0.0656, -0.2898],
#         [-0.1559,  0.1619, -0.3914],
#         [-0.3300,  0.1171, -0.5898]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1482, -0.8289, -1.4013],
#         [-1.1000, -0.8752, -1.3850],
#         [-1.1073, -0.9323, -1.2877],
#         [-1.1519, -0.8341, -1.3874],
#         [-1.2045, -0.7574, -1.4643]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0440828800201416
#
# tag_scores is
#
# tensor([[-1.1482, -0.8289, -1.4013],
#         [-1.1000, -0.8752, -1.3850],
#         [-1.1073, -0.9323, -1.2877],
#         [-1.1519, -0.8341, -1.3874],
#         [-1.2045, -0.7574, -1.4643]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0793, -1.5272,  1.4679,  0.0602,  0.8115,  0.1566],
#         [ 0.1757, -0.8632, -0.2495, -0.9730,  0.3834, -0.3898],
#         [ 0.8945,  0.1097, -1.6611, -0.5770, -0.6193,  0.4500],
#         [ 1.2335, -0.3852,  0.8937, -0.2992, -0.3456, -0.4636]])
# tag_space is
# tensor([[-0.1461,  0.1833, -0.3617],
#         [-0.1323,  0.1992, -0.4772],
#         [-0.1117,  0.1681, -0.5971],
#         [-0.2259,  0.1676, -0.6361]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1619, -0.8326, -1.3776],
#         [-1.1318, -0.8003, -1.4768],
#         [-1.0779, -0.7980, -1.5633],
#         [-1.1460, -0.7525, -1.5562]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0349355936050415
#
# tag_scores is
#
# tensor([[-1.1619, -0.8326, -1.3776],
#         [-1.1318, -0.8003, -1.4768],
#         [-1.0779, -0.7980, -1.5633],
#         [-1.1460, -0.7525, -1.5562]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2581, -1.2059,  0.1812,  0.9640,  0.7770,  0.7931],
#         [-1.0233, -2.1627, -0.9732,  0.0768, -0.5796, -0.9995],
#         [-1.0214, -1.6978,  1.7030, -0.2730, -0.8312, -0.4891],
#         [-0.5465,  0.0787, -0.1375,  0.1269,  0.8226,  1.2559],
#         [ 0.1372,  1.6046,  0.8099,  0.0620, -0.7932, -0.4802]])
# tag_space is
# tensor([[-0.1320,  0.1864, -0.3899],
#         [-0.1174,  0.1071, -0.4051],
#         [-0.1089,  0.0671, -0.2900],
#         [-0.1532,  0.1621, -0.3932],
#         [-0.3302,  0.1229, -0.5952]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1466, -0.8282, -1.4046],
#         [-1.0991, -0.8747, -1.3869],
#         [-1.1076, -0.9315, -1.2886],
#         [-1.1497, -0.8344, -1.3897],
#         [-1.2061, -0.7530, -1.4711]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0425077676773071
#
# tag_scores is
#
# tensor([[-1.1466, -0.8282, -1.4046],
#         [-1.0991, -0.8747, -1.3869],
#         [-1.1076, -0.9315, -1.2886],
#         [-1.1497, -0.8344, -1.3897],
#         [-1.2061, -0.7530, -1.4711]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0795, -1.5263,  1.4675,  0.0602,  0.8122,  0.1563],
#         [ 0.1747, -0.8642, -0.2489, -0.9729,  0.3829, -0.3894],
#         [ 0.8944,  0.1093, -1.6617, -0.5774, -0.6199,  0.4502],
#         [ 1.2340, -0.3839,  0.8934, -0.2991, -0.3447, -0.4641]])
# tag_space is
# tensor([[-0.1462,  0.1859, -0.3660],
#         [-0.1308,  0.2004, -0.4802],
#         [-0.1090,  0.1687, -0.6004],
#         [-0.2261,  0.1723, -0.6422]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1621, -0.8299, -1.3819],
#         [-1.1307, -0.7995, -1.4801],
#         [-1.0756, -0.7979, -1.5670],
#         [-1.1471, -0.7487, -1.5632]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0335803031921387
#
# tag_scores is
#
# tensor([[-1.1621, -0.8299, -1.3819],
#         [-1.1307, -0.7995, -1.4801],
#         [-1.0756, -0.7979, -1.5670],
#         [-1.1471, -0.7487, -1.5632]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2581, -1.2065,  0.1809,  0.9638,  0.7765,  0.7934],
#         [-1.0232, -2.1627, -0.9732,  0.0768, -0.5794, -0.9999],
#         [-1.0218, -1.6982,  1.7036, -0.2725, -0.8312, -0.4890],
#         [-0.5464,  0.0780, -0.1379,  0.1264,  0.8220,  1.2561],
#         [ 0.1377,  1.6051,  0.8097,  0.0620, -0.7928, -0.4804]])
# tag_space is
# tensor([[-0.1302,  0.1870, -0.3929],
#         [-0.1161,  0.1078, -0.4064],
#         [-0.1085,  0.0684, -0.2898],
#         [-0.1505,  0.1620, -0.3946],
#         [-0.3304,  0.1286, -0.6005]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1450, -0.8277, -1.4077],
#         [-1.0983, -0.8743, -1.3886],
#         [-1.1078, -0.9309, -1.2891],
#         [-1.1475, -0.8349, -1.3916],
#         [-1.2077, -0.7487, -1.4778]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0409300327301025
#
# tag_scores is
#
# tensor([[-1.1450, -0.8277, -1.4077],
#         [-1.0983, -0.8743, -1.3886],
#         [-1.1078, -0.9309, -1.2891],
#         [-1.1475, -0.8349, -1.3916],
#         [-1.2077, -0.7487, -1.4778]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.0797, -1.5253,  1.4671,  0.0601,  0.8129,  0.1559],
#         [ 0.1736, -0.8652, -0.2483, -0.9727,  0.3824, -0.3890],
#         [ 0.8943,  0.1089, -1.6624, -0.5778, -0.6206,  0.4505],
#         [ 1.2345, -0.3826,  0.8930, -0.2990, -0.3439, -0.4645]])
# tag_space is
# tensor([[-0.1464,  0.1884, -0.3701],
#         [-0.1293,  0.2014, -0.4829],
#         [-0.1062,  0.1692, -0.6034],
#         [-0.2263,  0.1769, -0.6482]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-1.1623, -0.8275, -1.3860],
#         [-1.1295, -0.7987, -1.4831],
#         [-1.0734, -0.7980, -1.5706],
#         [-1.1482, -0.7449, -1.5701]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 1.0322213172912598
#
# tag_scores is
#
# tensor([[-1.1623, -0.8275, -1.3860],
#         [-1.1295, -0.7987, -1.4831],
#         [-1.0734, -0.7980, -1.5706],
#         [-1.1482, -0.7449, -1.5701]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.2580, -1.2070,  0.1806,  0.9637,  0.7761,  0.7937],
#         [-1.0231, -2.1625, -0.9732,  0.0769, -0.5793, -1.0004],
#         [-1.0222, -1.6986,  1.7043, -0.2720, -0.8312, -0.4889],
#         [-0.5463,  0.0774, -0.1384,  0.1259,  0.8213,  1.2563],
#         [ 0.1381,  1.6055,  0.8095,  0.0619, -0.7924, -0.4806]])
# tag_space is
# tensor([[-0.1285,  0.1875, -0.3957],
#         [-0.1149,  0.1084, -0.4075],
#         [-0.1080,  0.0694, -0.2894],
#         [-0.1478,  0.1618, -0.3959],
#         [-0.3307,  0.1341, -0.6055]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-1.1433, -0.8273, -1.4105],
#         [-1.0974, -0.8742, -1.3900],
#         [-1.1079, -0.9306, -1.2894],
#         [-1.1452, -0.8356, -1.3933],
#         [-1.2094, -0.7446, -1.4842]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 1.0393474102020264
#
# tag_scores is
#
# tensor([[-1.1433, -0.8273, -1.4105],
#         [-1.0974, -0.8742, -1.3900],
#         [-1.1079, -0.9306, -1.2894],
#         [-1.1452, -0.8356, -1.3933],
#         [-1.2094, -0.7446, -1.4842]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# ...
#         [-0.0300, -4.5239, -3.9804],
#         [-5.4966, -0.0083, -5.4865]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.045991621911525726
#
# tag_scores is
#
# tensor([[-5.5393, -0.0569, -2.9689],
#         [-3.2218, -3.0982, -0.0888],
#         [-0.0300, -4.5239, -3.9804],
#         [-5.4966, -0.0083, -5.4865]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3577, -1.2476, -0.1708,  0.9528,  0.7628,  1.1807],
#         [-0.9524, -2.1551, -1.2231,  0.3540, -0.8022, -1.5971],
#         [-1.1749, -1.9640,  1.9165, -0.2914, -0.9327, -0.3782],
#         [-0.3495, -0.0029, -0.4664,  0.1199,  0.8636,  1.4903],
#         [ 0.3419,  1.6441,  0.9168,  0.1669, -0.8501, -0.6405]])
# tag_space is
# tensor([[ 2.4462, -0.9983, -1.8579],
#         [-1.7609,  1.6417, -1.1060],
#         [-1.3481, -1.1368,  2.2704],
#         [ 2.3802, -1.8011, -0.8443],
#         [-1.5084,  2.7106, -2.2970]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0444, -3.4889, -4.3485],
#         [-3.4955, -0.0929, -2.8406],
#         [-3.6767, -3.4654, -0.0582],
#         [-0.0536, -4.2349, -3.2781],
#         [-4.2401, -0.0212, -5.0288]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05406727269291878
#
# tag_scores is
#
# tensor([[-0.0444, -3.4889, -4.3485],
#         [-3.4955, -0.0929, -2.8406],
#         [-3.6767, -3.4654, -0.0582],
#         [-0.0536, -4.2349, -3.2781],
#         [-4.2401, -0.0212, -5.0288]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3650, -1.3117,  1.7513,  0.1621,  0.9925, -0.1008],
#         [-0.0226, -1.5184,  0.1001, -1.2457,  0.2103, -0.3203],
#         [ 1.0013,  0.0998, -1.9718, -0.6070, -0.6228,  0.7211],
#         [ 1.4908, -0.1840,  1.0309, -0.1736, -0.3637, -0.6500]])
# tag_space is
# tensor([[-2.8802,  2.6118, -0.3075],
#         [-1.1328, -1.0103,  2.0081],
#         [ 2.7611, -1.7413, -1.1967],
#         [-2.2085,  3.2887, -2.2004]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5485, -0.0565, -2.9758],
#         [-3.2290, -3.1065, -0.0881],
#         [-0.0297, -4.5321, -3.9875],
#         [-5.5054, -0.0082, -5.4973]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04563236981630325
#
# tag_scores is
#
# tensor([[-5.5485, -0.0565, -2.9758],
#         [-3.2290, -3.1065, -0.0881],
#         [-0.0297, -4.5321, -3.9875],
#         [-5.5054, -0.0082, -5.4973]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3579, -1.2477, -0.1712,  0.9528,  0.7628,  1.1812],
#         [-0.9522, -2.1552, -1.2234,  0.3546, -0.8024, -1.5980],
#         [-1.1752, -1.9644,  1.9168, -0.2916, -0.9329, -0.3780],
#         [-0.3490, -0.0030, -0.4669,  0.1202,  0.8637,  1.4907],
#         [ 0.3422,  1.6439,  0.9170,  0.1669, -0.8502, -0.6407]])
# tag_space is
# tensor([[ 2.4513, -0.9997, -1.8619],
#         [-1.7646,  1.6475, -1.1097],
#         [-1.3508, -1.1397,  2.2761],
#         [ 2.3856, -1.8044, -0.8463],
#         [-1.5099,  2.7158, -2.3010]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0441, -3.4950, -4.3573],
#         [-3.5042, -0.0921, -2.8492],
#         [-3.6846, -3.4736, -0.0577],
#         [-0.0532, -4.2431, -3.2851],
#         [-4.2467, -0.0210, -5.0378]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05362977460026741
#
# tag_scores is
#
# tensor([[-0.0441, -3.4950, -4.3573],
#         [-3.5042, -0.0921, -2.8492],
#         [-3.6846, -3.4736, -0.0577],
#         [-0.0532, -4.2431, -3.2851],
#         [-4.2467, -0.0210, -5.0378]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3656, -1.3113,  1.7514,  0.1626,  0.9928, -0.1009],
#         [-0.0228, -1.5193,  0.1010, -1.2463,  0.2099, -0.3203],
#         [ 1.0014,  0.0997, -1.9721, -0.6069, -0.6228,  0.7213],
#         [ 1.4909, -0.1840,  1.0310, -0.1735, -0.3637, -0.6501]])
# tag_space is
# tensor([[-2.8844,  2.6172, -0.3094],
#         [-1.1350, -1.0134,  2.0138],
#         [ 2.7664, -1.7444, -1.1987],
#         [-2.2110,  3.2950, -2.2049]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5577, -0.0561, -2.9826],
#         [-3.2362, -3.1147, -0.0874],
#         [-0.0295, -4.5402, -3.9946],
#         [-5.5141, -0.0081, -5.5081]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04527764022350311
#
# tag_scores is
#
# tensor([[-5.5577, -0.0561, -2.9826],
#         [-3.2362, -3.1147, -0.0874],
#         [-0.0295, -4.5402, -3.9946],
#         [-5.5141, -0.0081, -5.5081]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3581, -1.2478, -0.1715,  0.9528,  0.7629,  1.1817],
#         [-0.9519, -2.1553, -1.2238,  0.3552, -0.8026, -1.5988],
#         [-1.1754, -1.9648,  1.9172, -0.2918, -0.9330, -0.3778],
#         [-0.3486, -0.0031, -0.4673,  0.1204,  0.8639,  1.4910],
#         [ 0.3424,  1.6437,  0.9172,  0.1670, -0.8504, -0.6409]])
# tag_space is
# tensor([[ 2.4563, -1.0010, -1.8659],
#         [-1.7682,  1.6533, -1.1133],
#         [-1.3534, -1.1426,  2.2819],
#         [ 2.3909, -1.8076, -0.8483],
#         [-1.5114,  2.7209, -2.3050]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0438, -3.5011, -4.3660],
#         [-3.5128, -0.0912, -2.8578],
#         [-3.6925, -3.4817, -0.0573],
#         [-0.0528, -4.2513, -3.2920],
#         [-4.2532, -0.0209, -5.0468]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05319816991686821
#
# tag_scores is
#
# tensor([[-0.0438, -3.5011, -4.3660],
#         [-3.5128, -0.0912, -2.8578],
#         [-3.6925, -3.4817, -0.0573],
#         [-0.0528, -4.2513, -3.2920],
#         [-4.2532, -0.0209, -5.0468]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3662, -1.3109,  1.7516,  0.1632,  0.9930, -0.1011],
#         [-0.0229, -1.5202,  0.1019, -1.2469,  0.2095, -0.3204],
#         [ 1.0016,  0.0997, -1.9724, -0.6069, -0.6228,  0.7216],
#         [ 1.4910, -0.1840,  1.0310, -0.1735, -0.3638, -0.6502]])
# tag_space is
# tensor([[-2.8886,  2.6226, -0.3112],
#         [-1.1371, -1.0166,  2.0195],
#         [ 2.7716, -1.7474, -1.2008],
#         [-2.2134,  3.3013, -2.2094]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5668, -0.0557, -2.9895],
#         [-3.2433, -3.1229, -0.0867],
#         [-0.0293, -4.5483, -4.0016],
#         [-5.5228, -0.0080, -5.5188]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04492732509970665
#
# tag_scores is
#
# tensor([[-5.5668, -0.0557, -2.9895],
#         [-3.2433, -3.1229, -0.0867],
#         [-0.0293, -4.5483, -4.0016],
#         [-5.5228, -0.0080, -5.5188]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3583, -1.2479, -0.1719,  0.9528,  0.7629,  1.1823],
#         [-0.9517, -2.1553, -1.2241,  0.3558, -0.8029, -1.5997],
#         [-1.1757, -1.9652,  1.9175, -0.2920, -0.9332, -0.3775],
#         [-0.3482, -0.0032, -0.4678,  0.1207,  0.8640,  1.4913],
#         [ 0.3426,  1.6435,  0.9174,  0.1671, -0.8505, -0.6411]])
# tag_space is
# tensor([[ 2.4613, -1.0024, -1.8698],
#         [-1.7719,  1.6590, -1.1169],
#         [-1.3560, -1.1455,  2.2875],
#         [ 2.3962, -1.8109, -0.8503],
#         [-1.5129,  2.7260, -2.3090]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0435, -3.5072, -4.3746],
#         [-3.5213, -0.0904, -2.8664],
#         [-3.7004, -3.4898, -0.0568],
#         [-0.0524, -4.2595, -3.2989],
#         [-4.2596, -0.0207, -5.0558]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05277237296104431
#
# tag_scores is
#
# tensor([[-0.0435, -3.5072, -4.3746],
#         [-3.5213, -0.0904, -2.8664],
#         [-3.7004, -3.4898, -0.0568],
#         [-0.0524, -4.2595, -3.2989],
#         [-4.2596, -0.0207, -5.0558]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3667, -1.3105,  1.7517,  0.1637,  0.9932, -0.1012],
#         [-0.0230, -1.5210,  0.1028, -1.2474,  0.2091, -0.3204],
#         [ 1.0017,  0.0996, -1.9727, -0.6068, -0.6228,  0.7219],
#         [ 1.4911, -0.1840,  1.0310, -0.1734, -0.3639, -0.6503]])
# tag_space is
# tensor([[-2.8927,  2.6279, -0.3131],
#         [-1.1392, -1.0198,  2.0252],
#         [ 2.7768, -1.7505, -1.2028],
#         [-2.2159,  3.3076, -2.2139]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5758, -0.0553, -2.9963],
#         [-3.2504, -3.1310, -0.0860],
#         [-0.0291, -4.5563, -4.0087],
#         [-5.5314, -0.0080, -5.5294]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.044581346213817596
#
# tag_scores is
#
# tensor([[-5.5758, -0.0553, -2.9963],
#         [-3.2504, -3.1310, -0.0860],
#         [-0.0291, -4.5563, -4.0087],
#         [-5.5314, -0.0080, -5.5294]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3585, -1.2480, -0.1723,  0.9529,  0.7629,  1.1828],
#         [-0.9514, -2.1554, -1.2245,  0.3564, -0.8031, -1.6005],
#         [-1.1759, -1.9657,  1.9179, -0.2922, -0.9333, -0.3773],
#         [-0.3477, -0.0033, -0.4682,  0.1209,  0.8642,  1.4916],
#         [ 0.3428,  1.6434,  0.9176,  0.1671, -0.8506, -0.6413]])
# tag_space is
# tensor([[ 2.4662, -1.0038, -1.8737],
#         [-1.7754,  1.6647, -1.1206],
#         [-1.3586, -1.1484,  2.2932],
#         [ 2.4015, -1.8141, -0.8522],
#         [-1.5144,  2.7311, -2.3130]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0432, -3.5132, -4.3832],
#         [-3.5298, -0.0896, -2.8749],
#         [-3.7081, -3.4979, -0.0563],
#         [-0.0520, -4.2676, -3.3057],
#         [-4.2661, -0.0206, -5.0647]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05235227197408676
#
# tag_scores is
#
# tensor([[-0.0432, -3.5132, -4.3832],
#         [-3.5298, -0.0896, -2.8749],
#         [-3.7081, -3.4979, -0.0563],
#         [-0.0520, -4.2676, -3.3057],
#         [-4.2661, -0.0206, -5.0647]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3673, -1.3101,  1.7518,  0.1642,  0.9934, -0.1013],
#         [-0.0231, -1.5219,  0.1038, -1.2480,  0.2086, -0.3204],
#         [ 1.0018,  0.0996, -1.9730, -0.6068, -0.6228,  0.7222],
#         [ 1.4912, -0.1840,  1.0311, -0.1733, -0.3639, -0.6503]])
# tag_space is
# tensor([[-2.8968,  2.6332, -0.3150],
#         [-1.1413, -1.0229,  2.0309],
#         [ 2.7819, -1.7535, -1.2048],
#         [-2.2183,  3.3138, -2.2183]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5848, -0.0549, -3.0031],
#         [-3.2575, -3.1391, -0.0853],
#         [-0.0289, -4.5643, -4.0156],
#         [-5.5399, -0.0079, -5.5400]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04423963278532028
#
# tag_scores is
#
# tensor([[-5.5848, -0.0549, -3.0031],
#         [-3.2575, -3.1391, -0.0853],
#         [-0.0289, -4.5643, -4.0156],
#         [-5.5399, -0.0079, -5.5400]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3586, -1.2482, -0.1726,  0.9529,  0.7629,  1.1833],
#         [-0.9512, -2.1555, -1.2248,  0.3569, -0.8033, -1.6013],
#         [-1.1761, -1.9661,  1.9182, -0.2924, -0.9334, -0.3771],
#         [-0.3473, -0.0034, -0.4687,  0.1212,  0.8643,  1.4920],
#         [ 0.3430,  1.6432,  0.9178,  0.1672, -0.8507, -0.6415]])
# tag_space is
# tensor([[ 2.4712, -1.0052, -1.8776],
#         [-1.7790,  1.6704, -1.1242],
#         [-1.3612, -1.1512,  2.2988],
#         [ 2.4067, -1.8173, -0.8541],
#         [-1.5158,  2.7362, -2.3169]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0429, -3.5192, -4.3917],
#         [-3.5382, -0.0888, -2.8834],
#         [-3.7159, -3.5060, -0.0559],
#         [-0.0516, -4.2757, -3.3125],
#         [-4.2724, -0.0204, -5.0735]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.0519377663731575
#
# tag_scores is
#
# tensor([[-0.0429, -3.5192, -4.3917],
#         [-3.5382, -0.0888, -2.8834],
#         [-3.7159, -3.5060, -0.0559],
#         [-0.0516, -4.2757, -3.3125],
#         [-4.2724, -0.0204, -5.0735]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3679, -1.3097,  1.7520,  0.1648,  0.9937, -0.1015],
#         [-0.0232, -1.5228,  0.1047, -1.2486,  0.2082, -0.3205],
#         [ 1.0020,  0.0996, -1.9732, -0.6067, -0.6227,  0.7224],
#         [ 1.4913, -0.1840,  1.0311, -0.1733, -0.3640, -0.6504]])
# tag_space is
# tensor([[-2.9009,  2.6385, -0.3169],
#         [-1.1434, -1.0260,  2.0365],
#         [ 2.7870, -1.7565, -1.2069],
#         [-2.2207,  3.3200, -2.2228]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.5938, -0.0545, -3.0098],
#         [-3.2646, -3.1472, -0.0847],
#         [-0.0286, -4.5722, -4.0226],
#         [-5.5484, -0.0078, -5.5505]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04390212148427963
#
# tag_scores is
#
# tensor([[-5.5938, -0.0545, -3.0098],
#         [-3.2646, -3.1472, -0.0847],
#         [-0.0286, -4.5722, -4.0226],
#         [-5.5484, -0.0078, -5.5505]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3588, -1.2483, -0.1730,  0.9529,  0.7630,  1.1838],
#         [-0.9509, -2.1555, -1.2252,  0.3575, -0.8035, -1.6021],
#         [-1.1764, -1.9665,  1.9185, -0.2926, -0.9336, -0.3769],
#         [-0.3469, -0.0035, -0.4691,  0.1214,  0.8645,  1.4923],
#         [ 0.3432,  1.6430,  0.9180,  0.1672, -0.8508, -0.6417]])
# tag_space is
# tensor([[ 2.4761, -1.0065, -1.8815],
#         [-1.7825,  1.6760, -1.1277],
#         [-1.3637, -1.1541,  2.3044],
#         [ 2.4120, -1.8205, -0.8561],
#         [-1.5173,  2.7412, -2.3208]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0426, -3.5252, -4.4002],
#         [-3.5466, -0.0881, -2.8918],
#         [-3.7236, -3.5140, -0.0554],
#         [-0.0513, -4.2837, -3.3193],
#         [-4.2788, -0.0203, -5.0823]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# loss is
#
# 0.05152872949838638
#
# tag_scores is
#
# tensor([[-0.0426, -3.5252, -4.4002],
#         [-3.5466, -0.0881, -2.8918],
#         [-3.7236, -3.5140, -0.0554],
#         [-0.0513, -4.2837, -3.3193],
#         [-4.2788, -0.0203, -5.0823]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# sentence is tensor([ 5,  6,  7,  8])
# embeds is tensor([[ 1.3684, -1.3093,  1.7521,  0.1653,  0.9939, -0.1016],
#         [-0.0233, -1.5237,  0.1056, -1.2492,  0.2078, -0.3205],
#         [ 1.0021,  0.0995, -1.9735, -0.6067, -0.6227,  0.7227],
#         [ 1.4914, -0.1840,  1.0311, -0.1732, -0.3641, -0.6505]])
# tag_space is
# tensor([[-2.9049,  2.6437, -0.3188],
#         [-1.1455, -1.0291,  2.0421],
#         [ 2.7921, -1.7595, -1.2089],
#         [-2.2231,  3.3261, -2.2271]])
# , tag_space.size is
# torch.Size([4, 3])
#
# tag_scores is
# tensor([[-5.6027, -0.0541, -3.0166],
#         [-3.2716, -3.1552, -0.0840],
#         [-0.0284, -4.5801, -4.0295],
#         [-5.5569, -0.0077, -5.5610]])
# , tag_scores.size is
# torch.Size([4, 3])
#
# loss is
#
# 0.04356870800256729
#
# tag_scores is
#
# tensor([[-5.6027, -0.0541, -3.0166],
#         [-3.2716, -3.1552, -0.0840],
#         [-0.0284, -4.5801, -4.0295],
#         [-5.5569, -0.0077, -5.5610]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# sentence is tensor([ 0,  1,  2,  3,  4])
# embeds is tensor([[ 0.3590, -1.2484, -0.1734,  0.9529,  0.7630,  1.1843],
#         [-0.9507, -2.1556, -1.2255,  0.3581, -0.8037, -1.6029],
#         [-1.1766, -1.9669,  1.9189, -0.2928, -0.9337, -0.3767],
#         [-0.3465, -0.0036, -0.4696,  0.1217,  0.8646,  1.4926],
#         [ 0.3434,  1.6428,  0.9182,  0.1673, -0.8510, -0.6419]])
# tag_space is
# tensor([[ 2.1371, -0.5711, -2.1772],
#         [-1.9018,  1.7633, -1.1767],
#         [-1.4067, -1.1351,  2.2910],
#         [ 2.3980, -1.8214, -0.8595],
#         [-1.5480,  2.7535, -2.3184]])
# , tag_space.size is
# torch.Size([5, 3])
#
# tag_scores is
# tensor([[-0.0770, -2.7852, -4.3912],
#         [-3.7407, -0.0755, -3.0156],
#         [-3.7534, -3.4818, -0.0557],
#         [-0.0518, -4.2712, -3.3093],
#         [-4.3211, -0.0196, -5.0915]])
# , tag_scores.size is
# torch.Size([5, 3])
#
# tensor([[-0.0770, -2.7852, -4.3912],
#         [-3.7407, -0.0755, -3.0156],
#         [-3.7534, -3.4818, -0.0557],
#         [-0.0518, -4.2712, -3.3093],
#         [-4.3211, -0.0196, -5.0915]])

# %%
tensor = torch.tensor([[-0.1663,  0.1064, -0.2628],
        [-0.1388,  0.0170, -0.3017],
        [-0.1074, -0.0396, -0.2060],
        [-0.2053,  0.0895, -0.2832],
        [-0.3295, -0.0609, -0.4147]])

# %%
tensor
# Out:
# tensor([[-0.1663,  0.1064, -0.2628],
#         [-0.1388,  0.0170, -0.3017],
#         [-0.1074, -0.0396, -0.2060],
#         [-0.2053,  0.0895, -0.2832],
#         [-0.3295, -0.0609, -0.4147]])

# %%
torch.max(tensor, dim=1)
# Out:
# (tensor([ 0.1064,  0.0170, -0.0396,  0.0895, -0.0609]),
#  tensor([ 1,  1,  1,  1,  1]))
