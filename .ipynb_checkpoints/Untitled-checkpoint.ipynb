# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %%
criterion = nn.CrossEntropyLoss()

# %%
output = torch.rand(1,3)

# %%
target = torch.Tensor([0])

# %%
output
# Out:
# tensor([[ 0.7576,  0.2793,  0.4031]])

# %%
target.size()
# Out:
# torch.Size([1])

# %%
output
# Out:
# tensor([[ 0.7576,  0.2793,  0.4031]])

# %%
_, pred = torch.max(output, 1)

# %%
pred
# Out:
# tensor([ 0])

# %%
a = torch.Tensor([2.])

# %%
a
# Out:
# tensor([ 2.])

# %%
a.item()
# Out:
# 2.0

# %%
pred.item()
# Out:
# 0

# %%
a.item() == pred.item()
# Out:
# False

# %%
print("\%")
# Out:
# \%

# %%
import numpy as np

# %%
a = np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,a)
plt.show()

# %%
w = torch.randn(3, 5)

# %%
w
# Out:
# tensor([[ 0.7244, -0.7022,  1.1661,  0.2605,  0.3506],
#         [ 1.0203, -1.8349, -2.2149,  0.0436,  1.3240],
#         [-0.1005,  0.6443,  0.5244,  1.0157,  0.2571]])

# %%
nn.init.orthogonal_(w)
# Out:
# tensor([[-0.5867,  0.5298,  0.2520,  0.3527,  0.4327],
#         [ 0.4944, -0.1314,  0.3586,  0.7807, -0.0140],
#         [ 0.3486, -0.1315,  0.3837, -0.4059,  0.7411]])

# %%
training_data = [
    ("The dog ate the apple".split(), ["DET", "NN", "V", "DET", "NN"]),
    ("Everybody read that book".split(), ["NN", "V", "DET", "NN"])
]

# %%
training_data
# Out:
# [(['The', 'dog', 'ate', 'the', 'apple'], ['DET', 'NN', 'V', 'DET', 'NN']),
#  (['Everybody', 'read', 'that', 'book'], ['NN', 'V', 'DET', 'NN'])]

# %%
word_to_ix = {} # 单词的索引字典
for sent, tags in training_data:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
print(word_to_ix)
# Out:
# {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'that': 7, 'book': 8}

# %%
tag_to_ix = {"DET": 0, "NN": 1, "V": 2} # 手工设定词性标签数据字典
EMBEDDING_DIM = 6
HIDDEN_DIM = 6

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)
        self.hidden = self.init_hidden()

    def init_hidden(self):
        # Before we've done anything, we dont have any hidden state.
        # Refer to the Pytorch documentation to see exactly
        # why they have this dimensionality.
        # The axes semantics are (num_layers, minibatch_size, hidden_dim)
        return (torch.zeros(1, 1, self.hidden_dim),
                torch.zeros(1, 1, self.hidden_dim))

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, self.hidden = self.lstm(
            embeds.view(len(sentence), 1, -1), self.hidden)
        tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
        print("tag_space is \n{}\n, tag_space.size is \n{}\n".format(tag_space, tag_space.size())
        tag_scores = F.log_softmax(tag_space, dim=1)
        print("tag_scores is \n{}\n, tag_scores.size is \n{}\n".format(tag_scores, tag_scores.size())
        return tag_scores
# Out:
#   File "<ipython-input-87-57d066c66b21>", line 31
#     tag_scores = F.log_softmax(tag_space, dim=1)
#              ^
# SyntaxError: invalid syntax

# %%
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix), len(tag_to_ix))
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# See what the scores are before training
# Note that element i,j of the output is the score for tag j for word i.
# Here we don't need to train, so the code is wrapped in torch.no_grad()
with torch.no_grad():
    inputs = prepare_sequence(training_data[0][0], word_to_ix)
    tag_scores = model(inputs)
    print(tag_scores)

for epoch in range(300):  # again, normally you would NOT do 300 epochs, it is toy data
    for sentence, tags in training_data:
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Also, we need to clear out the hidden state of the LSTM,
        # detaching it from its history on the last instance.
        model.hidden = model.init_hidden()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.
        sentence_in = prepare_sequence(sentence, word_to_ix)
        targets = prepare_sequence(tags, tag_to_ix)

        # Step 3. Run our forward pass.
        tag_scores = model(sentence_in)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = loss_function(tag_scores, targets)
        print("loss is \n\n{}\n".format(loss))
        print("tag_scores is \n\n{}\n, targets is \n\n{}\n".format(tag_scores, targets))
        loss.backward()
        optimizer.step()

# See what the scores are after training
with torch.no_grad():
    inputs = prepare_sequence(training_data[0][0], word_to_ix)
    tag_scores = model(inputs)

    # The sentence is "the dog ate the apple".  i,j corresponds to score for tag j
    # for word i. The predicted tag is the maximum scoring tag.
    # Here, we can see the predicted sequence below is 0 1 2 0 1
    # since 0 is index of the maximum value of row 1,
    # 1 is the index of maximum value of row 2, etc.
    # Which is DET NOUN VERB DET NOUN, the correct sequence!
    print(tag_scores)
# Out:
# tensor([[-0.9062, -1.4053, -1.0480],
#         [-1.0069, -1.3206, -1.0005],
#         [-1.0433, -1.3571, -0.9408],
#         [-1.0693, -1.2794, -0.9714],
#         [-1.0429, -1.2830, -0.9933]])
# loss is
#
# 1.1040046215057373
#
# tag_scores is
#
# tensor([[-0.9062, -1.4053, -1.0480],
#         [-1.0069, -1.3206, -1.0005],
#         [-1.0433, -1.3571, -0.9408],
#         [-1.0693, -1.2794, -0.9714],
#         [-1.0429, -1.2830, -0.9933]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.1569550037384033
#
# tag_scores is
#
# tensor([[-0.9634, -1.3904, -0.9958],
#         [-1.0477, -1.3282, -0.9563],
#         [-1.0354, -1.2301, -1.0423],
#         [-1.0730, -1.2457, -0.9935]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.090120553970337
#
# tag_scores is
#
# tensor([[-0.9055, -1.3580, -1.0833],
#         [-1.0134, -1.2662, -1.0354],
#         [-1.0523, -1.3074, -0.9666],
#         [-1.0797, -1.2282, -1.0011],
#         [-1.0526, -1.2326, -1.0232]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.139481544494629
#
# tag_scores is
#
# tensor([[-0.9703, -1.3413, -1.0229],
#         [-1.0582, -1.2785, -0.9823],
#         [-1.0392, -1.1885, -1.0741],
#         [-1.0839, -1.1951, -1.0243]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0780049562454224
#
# tag_scores is
#
# tensor([[-0.9052, -1.3152, -1.1174],
#         [-1.0203, -1.2166, -1.0692],
#         [-1.0616, -1.2625, -0.9911],
#         [-1.0902, -1.1818, -1.0297],
#         [-1.0624, -1.1869, -1.0521]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.123993158340454
#
# tag_scores is
#
# tensor([[-0.9775, -1.2967, -1.0490],
#         [-1.0688, -1.2334, -1.0071],
#         [-1.0431, -1.1510, -1.1047],
#         [-1.0950, -1.1491, -1.0540]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.067411184310913
#
# tag_scores is
#
# tensor([[-0.9052, -1.2764, -1.1504],
#         [-1.0276, -1.1714, -1.1020],
#         [-1.0709, -1.2220, -1.0142],
#         [-1.1006, -1.1397, -1.0572],
#         [-1.0721, -1.1456, -1.0798]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.1102454662322998
#
# tag_scores is
#
# tensor([[-0.9847, -1.2561, -1.0739],
#         [-1.0795, -1.1924, -1.0307],
#         [-1.0468, -1.1171, -1.1341],
#         [-1.1061, -1.1074, -1.0825]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.058119773864746
#
# tag_scores is
#
# tensor([[-0.9053, -1.2414, -1.1821],
#         [-1.0351, -1.1302, -1.1337],
#         [-1.0802, -1.1855, -1.0360],
#         [-1.1109, -1.1016, -1.0835],
#         [-1.0816, -1.1082, -1.1063]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0980167388916016
#
# tag_scores is
#
# tensor([[-0.9919, -1.2192, -1.0976],
#         [-1.0902, -1.1553, -1.0530],
#         [-1.0504, -1.0865, -1.1622],
#         [-1.1171, -1.0695, -1.1099]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.049936056137085
#
# tag_scores is
#
# tensor([[-0.9054, -1.2099, -1.2128],
#         [-1.0426, -1.0926, -1.1644],
#         [-1.0892, -1.1526, -1.0563],
#         [-1.1210, -1.0671, -1.1086],
#         [-1.0907, -1.0744, -1.1316]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0871073007583618
#
# tag_scores is
#
# tensor([[-0.9989, -1.1858, -1.1202],
#         [-1.1007, -1.1217, -1.0740],
#         [-1.0536, -1.0591, -1.1890],
#         [-1.1279, -1.0350, -1.1361]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.042689323425293
#
# tag_scores is
#
# tensor([[-0.9052, -1.1815, -1.2423],
#         [-1.0501, -1.0583, -1.1939],
#         [-1.0981, -1.1231, -1.0753],
#         [-1.1307, -1.0358, -1.1324],
#         [-1.0994, -1.0439, -1.1556]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.077337384223938
#
# tag_scores is
#
# tensor([[-1.0058, -1.1554, -1.1416],
#         [-1.1109, -1.0912, -1.0938],
#         [-1.0564, -1.0344, -1.2145],
#         [-1.1384, -1.0037, -1.1610]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0362298488616943
#
# tag_scores is
#
# tensor([[-0.9049, -1.1559, -1.2706],
#         [-1.0573, -1.0271, -1.2223],
#         [-1.1066, -1.0965, -1.0928],
#         [-1.1400, -1.0075, -1.1550],
#         [-1.1077, -1.0163, -1.1784]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0685474872589111
#
# tag_scores is
#
# tensor([[-1.0123, -1.1278, -1.1619],
#         [-1.1209, -1.0637, -1.1123],
#         [-1.0587, -1.0123, -1.2389],
#         [-1.1486, -0.9753, -1.1847]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0304276943206787
#
# tag_scores is
#
# tensor([[-0.9043, -1.1330, -1.2979],
#         [-1.0644, -0.9985, -1.2495],
#         [-1.1148, -1.0726, -1.1090],
#         [-1.1489, -0.9819, -1.1763],
#         [-1.1154, -0.9914, -1.2000]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0605955123901367
#
# tag_scores is
#
# tensor([[-1.0185, -1.1028, -1.1811],
#         [-1.1305, -1.0387, -1.1295],
#         [-1.0606, -0.9925, -1.2620],
#         [-1.1583, -0.9495, -1.2071]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0251708030700684
#
# tag_scores is
#
# tensor([[-0.9033, -1.1125, -1.3241],
#         [-1.0712, -0.9724, -1.2757],
#         [-1.1226, -1.0511, -1.1239],
#         [-1.1573, -0.9587, -1.1964],
#         [-1.1226, -0.9690, -1.2204]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0533562898635864
#
# tag_scores is
#
# tensor([[-1.0245, -1.0801, -1.1992],
#         [-1.1398, -1.0161, -1.1454],
#         [-1.0619, -0.9748, -1.2839],
#         [-1.1677, -0.9261, -1.2282]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0203619003295898
#
# tag_scores is
#
# tensor([[-0.9020, -1.0942, -1.3494],
#         [-1.0777, -0.9486, -1.3008],
#         [-1.1301, -1.0319, -1.1374],
#         [-1.1652, -0.9377, -1.2153],
#         [-1.1293, -0.9487, -1.2397]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0467196702957153
#
# tag_scores is
#
# tensor([[-1.0300, -1.0594, -1.2162],
#         [-1.1487, -0.9957, -1.1600],
#         [-1.0627, -0.9590, -1.3048],
#         [-1.1766, -0.9047, -1.2482]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.015918254852295
#
# tag_scores is
#
# tensor([[-0.9002, -1.0778, -1.3736],
#         [-1.0839, -0.9267, -1.3248],
#         [-1.1372, -1.0147, -1.1496],
#         [-1.1727, -0.9186, -1.2330],
#         [-1.1355, -0.9303, -1.2577]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0405889749526978
#
# tag_scores is
#
# tensor([[-1.0353, -1.0406, -1.2322],
#         [-1.1573, -0.9772, -1.1735],
#         [-1.0630, -0.9450, -1.3246],
#         [-1.1852, -0.8853, -1.2669]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0117690563201904
#
# tag_scores is
#
# tensor([[-0.8981, -1.0632, -1.3971],
#         [-1.0897, -0.9066, -1.3479],
#         [-1.1439, -0.9993, -1.1606],
#         [-1.1798, -0.9014, -1.2495],
#         [-1.1411, -0.9138, -1.2747]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0348799228668213
#
# tag_scores is
#
# tensor([[-1.0402, -1.0235, -1.2473],
#         [-1.1656, -0.9605, -1.1856],
#         [-1.0628, -0.9325, -1.3434],
#         [-1.1933, -0.8676, -1.2844]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0078537464141846
#
# tag_scores is
#
# tensor([[-0.8956, -1.0503, -1.4196],
#         [-1.0953, -0.8881, -1.3699],
#         [-1.1504, -0.9856, -1.1703],
#         [-1.1864, -0.8857, -1.2649],
#         [-1.1462, -0.8988, -1.2905]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0295188426971436
#
# tag_scores is
#
# tensor([[-1.0448, -1.0079, -1.2613],
#         [-1.1736, -0.9454, -1.1967],
#         [-1.0621, -0.9215, -1.3612],
#         [-1.2010, -0.8514, -1.3008]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0041210651397705
#
# tag_scores is
#
# tensor([[-0.8927, -1.0389, -1.4415],
#         [-1.1005, -0.8711, -1.3910],
#         [-1.1565, -0.9734, -1.1789],
#         [-1.1926, -0.8715, -1.2792],
#         [-1.1509, -0.8853, -1.3054]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0244417190551758
#
# tag_scores is
#
# tensor([[-1.0492, -0.9937, -1.2744],
#         [-1.1813, -0.9317, -1.2065],
#         [-1.0609, -0.9118, -1.3782],
#         [-1.2085, -0.8366, -1.3161]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 1.0005275011062622
#
# tag_scores is
#
# tensor([[-0.8893, -1.0288, -1.4626],
#         [-1.1055, -0.8554, -1.4113],
#         [-1.1624, -0.9625, -1.1864],
#         [-1.1984, -0.8586, -1.2925],
#         [-1.1550, -0.8731, -1.3193]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0195931196212769
#
# tag_scores is
#
# tensor([[-1.0533, -0.9808, -1.2867],
#         [-1.1888, -0.9194, -1.2152],
#         [-1.0592, -0.9032, -1.3943],
#         [-1.2155, -0.8231, -1.3303]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9970361590385437
#
# tag_scores is
#
# tensor([[-0.8856, -1.0200, -1.4830],
#         [-1.1102, -0.8408, -1.4307],
#         [-1.1680, -0.9529, -1.1928],
#         [-1.2038, -0.8469, -1.3048],
#         [-1.1588, -0.8621, -1.3323]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0149247646331787
#
# tag_scores is
#
# tensor([[-1.0571, -0.9689, -1.2981],
#         [-1.1961, -0.9082, -1.2229],
#         [-1.0572, -0.8957, -1.4096],
#         [-1.2224, -0.8107, -1.3435]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.993615984916687
#
# tag_scores is
#
# tensor([[-0.8816, -1.0123, -1.5029],
#         [-1.1146, -0.8273, -1.4494],
#         [-1.1734, -0.9443, -1.1982],
#         [-1.2089, -0.8363, -1.3161],
#         [-1.1621, -0.8521, -1.3444]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0103951692581177
#
# tag_scores is
#
# tensor([[-1.0607, -0.9581, -1.3087],
#         [-1.2032, -0.8982, -1.2294],
#         [-1.0547, -0.8892, -1.4242],
#         [-1.2289, -0.7994, -1.3557]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9902405738830566
#
# tag_scores is
#
# tensor([[-0.8771, -1.0057, -1.5222],
#         [-1.1188, -0.8147, -1.4673],
#         [-1.1786, -0.9368, -1.2025],
#         [-1.2137, -0.8266, -1.3266],
#         [-1.1651, -0.8431, -1.3558]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0059678554534912
#
# tag_scores is
#
# tensor([[-1.0641, -0.9481, -1.3186],
#         [-1.2102, -0.8891, -1.2350],
#         [-1.0518, -0.8835, -1.4382],
#         [-1.2352, -0.7889, -1.3669]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9868873357772827
#
# tag_scores is
#
# tensor([[-0.8724, -1.0000, -1.5411],
#         [-1.1227, -0.8029, -1.4846],
#         [-1.1837, -0.9303, -1.2060],
#         [-1.2182, -0.8178, -1.3362],
#         [-1.1677, -0.8349, -1.3664]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 1.0016120672225952
#
# tag_scores is
#
# tensor([[-1.0674, -0.9390, -1.3277],
#         [-1.2170, -0.8809, -1.2396],
#         [-1.0486, -0.8786, -1.4515],
#         [-1.2414, -0.7792, -1.3773]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9835377931594849
#
# tag_scores is
#
# tensor([[-0.8673, -0.9952, -1.5595],
#         [-1.1265, -0.7919, -1.5012],
#         [-1.1886, -0.9245, -1.2085],
#         [-1.2224, -0.8098, -1.3450],
#         [-1.1700, -0.8275, -1.3762]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9973002672195435
#
# tag_scores is
#
# tensor([[-1.0706, -0.9306, -1.3361],
#         [-1.2238, -0.8736, -1.2433],
#         [-1.0451, -0.8745, -1.4643],
#         [-1.2474, -0.7703, -1.3868]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9801756143569946
#
# tag_scores is
#
# tensor([[-0.8619, -0.9911, -1.5776],
#         [-1.1301, -0.7816, -1.5173],
#         [-1.1935, -0.9196, -1.2102],
#         [-1.2264, -0.8025, -1.3531],
#         [-1.1720, -0.8208, -1.3855]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9930098056793213
#
# tag_scores is
#
# tensor([[-1.0736, -0.9228, -1.3439],
#         [-1.2306, -0.8669, -1.2460],
#         [-1.0412, -0.8710, -1.4765],
#         [-1.2533, -0.7620, -1.3955]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9767870903015137
#
# tag_scores is
#
# tensor([[-0.8562, -0.9878, -1.5953],
#         [-1.1335, -0.7718, -1.5328],
#         [-1.1983, -0.9153, -1.2110],
#         [-1.2302, -0.7958, -1.3604],
#         [-1.1737, -0.8147, -1.3942]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9887200593948364
#
# tag_scores is
#
# tensor([[-1.0766, -0.9156, -1.3511],
#         [-1.2374, -0.8610, -1.2479],
#         [-1.0371, -0.8681, -1.4883],
#         [-1.2590, -0.7543, -1.4034]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.973360538482666
#
# tag_scores is
#
# tensor([[-0.8502, -0.9852, -1.6128],
#         [-1.1368, -0.7626, -1.5478],
#         [-1.2030, -0.9117, -1.2111],
#         [-1.2337, -0.7897, -1.3672],
#         [-1.1752, -0.8092, -1.4023]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9844136238098145
#
# tag_scores is
#
# tensor([[-1.0795, -0.9089, -1.3577],
#         [-1.2442, -0.8556, -1.2489],
#         [-1.0326, -0.8657, -1.4997],
#         [-1.2648, -0.7472, -1.4107]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9698858261108398
#
# tag_scores is
#
# tensor([[-0.8440, -0.9833, -1.6301],
#         [-1.1400, -0.7538, -1.5625],
#         [-1.2078, -0.9087, -1.2104],
#         [-1.2371, -0.7841, -1.3733],
#         [-1.1764, -0.8041, -1.4100]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9800755977630615
#
# tag_scores is
#
# tensor([[-1.0823, -0.9027, -1.3637],
#         [-1.2510, -0.8509, -1.2492],
#         [-1.0280, -0.8639, -1.5107],
#         [-1.2704, -0.7404, -1.4172]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9663543701171875
#
# tag_scores is
#
# tensor([[-0.8375, -0.9819, -1.6472],
#         [-1.1432, -0.7454, -1.5767],
#         [-1.2125, -0.9062, -1.2090],
#         [-1.2403, -0.7790, -1.3789],
#         [-1.1774, -0.7995, -1.4173]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9756927490234375
#
# tag_scores is
#
# tensor([[-1.0852, -0.8968, -1.3692],
#         [-1.2579, -0.8466, -1.2487],
#         [-1.0231, -0.8625, -1.5214],
#         [-1.2761, -0.7341, -1.4231]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9627584218978882
#
# tag_scores is
#
# tensor([[-0.8307, -0.9811, -1.6641],
#         [-1.1462, -0.7374, -1.5906],
#         [-1.2173, -0.9042, -1.2069],
#         [-1.2434, -0.7743, -1.3840],
#         [-1.1781, -0.7953, -1.4242]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9712536334991455
#
# tag_scores is
#
# tensor([[-1.0881, -0.8913, -1.3742],
#         [-1.2649, -0.8428, -1.2475],
#         [-1.0180, -0.8615, -1.5319],
#         [-1.2818, -0.7282, -1.4285]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9590914845466614
#
# tag_scores is
#
# tensor([[-0.8238, -0.9807, -1.6810],
#         [-1.1492, -0.7297, -1.6042],
#         [-1.2222, -0.9027, -1.2042],
#         [-1.2463, -0.7700, -1.3886],
#         [-1.1787, -0.7915, -1.4308]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9667484164237976
#
# tag_scores is
#
# tensor([[-1.0910, -0.8862, -1.3788],
#         [-1.2721, -0.8394, -1.2456],
#         [-1.0127, -0.8608, -1.5420],
#         [-1.2875, -0.7226, -1.4333]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9553475379943848
#
# tag_scores is
#
# tensor([[-0.8166, -0.9809, -1.6978],
#         [-1.1522, -0.7223, -1.6175],
#         [-1.2271, -0.9016, -1.2009],
#         [-1.2491, -0.7660, -1.3927],
#         [-1.1790, -0.7879, -1.4371]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.962168276309967
#
# tag_scores is
#
# tensor([[-1.0940, -0.8812, -1.3828],
#         [-1.2793, -0.8364, -1.2430],
#         [-1.0072, -0.8606, -1.5520],
#         [-1.2933, -0.7172, -1.4375]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9515215754508972
#
# tag_scores is
#
# tensor([[-0.8092, -0.9815, -1.7146],
#         [-1.1551, -0.7151, -1.6305],
#         [-1.2321, -0.9009, -1.1969],
#         [-1.2518, -0.7624, -1.3965],
#         [-1.1792, -0.7846, -1.4432]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9575057029724121
#
# tag_scores is
#
# tensor([[-1.0971, -0.8766, -1.3865],
#         [-1.2868, -0.8338, -1.2398],
#         [-1.0015, -0.8606, -1.5618],
#         [-1.2991, -0.7121, -1.4413]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9476088285446167
#
# tag_scores is
#
# tensor([[-0.8016, -0.9826, -1.7314],
#         [-1.1581, -0.7081, -1.6434],
#         [-1.2372, -0.9006, -1.1924],
#         [-1.2544, -0.7590, -1.4000],
#         [-1.1791, -0.7816, -1.4491]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9527537822723389
#
# tag_scores is
#
# tensor([[-1.1002, -0.8721, -1.3898],
#         [-1.2944, -0.8315, -1.2360],
#         [-0.9957, -0.8609, -1.5714],
#         [-1.3050, -0.7072, -1.4447]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9436051249504089
#
# tag_scores is
#
# tensor([[-0.7938, -0.9840, -1.7483],
#         [-1.1610, -0.7013, -1.6561],
#         [-1.2425, -0.9006, -1.1874],
#         [-1.2568, -0.7558, -1.4032],
#         [-1.1789, -0.7788, -1.4549]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9479067325592041
#
# tag_scores is
#
# tensor([[-1.1034, -0.8678, -1.3927],
#         [-1.3022, -0.8296, -1.2316],
#         [-0.9896, -0.8615, -1.5810],
#         [-1.3110, -0.7026, -1.4476]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9395064115524292
#
# tag_scores is
#
# tensor([[-0.7858, -0.9859, -1.7652],
#         [-1.1640, -0.6946, -1.6687],
#         [-1.2479, -0.9010, -1.1818],
#         [-1.2592, -0.7529, -1.4061],
#         [-1.1785, -0.7762, -1.4606]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9429590702056885
#
# tag_scores is
#
# tensor([[-1.1068, -0.8636, -1.3953],
#         [-1.3101, -0.8279, -1.2267],
#         [-0.9835, -0.8624, -1.5904],
#         [-1.3171, -0.6980, -1.4502]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9353094100952148
#
# tag_scores is
#
# tensor([[-0.7777, -0.9881, -1.7823],
#         [-1.1670, -0.6880, -1.6812],
#         [-1.2534, -0.9017, -1.1757],
#         [-1.2614, -0.7502, -1.4087],
#         [-1.1779, -0.7737, -1.4663]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9379060864448547
#
# tag_scores is
#
# tensor([[-1.1103, -0.8596, -1.3975],
#         [-1.3184, -0.8266, -1.2212],
#         [-0.9772, -0.8635, -1.5998],
#         [-1.3234, -0.6936, -1.4524]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9310108423233032
#
# tag_scores is
#
# tensor([[-0.7693, -0.9907, -1.7995],
#         [-1.1701, -0.6816, -1.6936],
#         [-1.2591, -0.9027, -1.1692],
#         [-1.2635, -0.7476, -1.4112],
#         [-1.1771, -0.7714, -1.4720]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.932743489742279
#
# tag_scores is
#
# tensor([[-1.1140, -0.8556, -1.3994],
#         [-1.3268, -0.8255, -1.2152],
#         [-0.9707, -0.8648, -1.6092],
#         [-1.3298, -0.6894, -1.4543]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9266077280044556
#
# tag_scores is
#
# tensor([[-0.7609, -0.9937, -1.8169],
#         [-1.1732, -0.6752, -1.7060],
#         [-1.2650, -0.9040, -1.1622],
#         [-1.2655, -0.7452, -1.4135],
#         [-1.1761, -0.7692, -1.4777]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9274674654006958
#
# tag_scores is
#
# tensor([[-1.1178, -0.8517, -1.4010],
#         [-1.3355, -0.8246, -1.2088],
#         [-0.9642, -0.8663, -1.6186],
#         [-1.3363, -0.6852, -1.4559]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9220973253250122
#
# tag_scores is
#
# tensor([[-0.7522, -0.9970, -1.8344],
#         [-1.1764, -0.6689, -1.7184],
#         [-1.2711, -0.9055, -1.1547],
#         [-1.2674, -0.7430, -1.4157],
#         [-1.1749, -0.7672, -1.4835]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9220743775367737
#
# tag_scores is
#
# tensor([[-1.1218, -0.8479, -1.4024],
#         [-1.3444, -0.8240, -1.2018],
#         [-0.9574, -0.8680, -1.6280],
#         [-1.3429, -0.6811, -1.4572]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.917477011680603
#
# tag_scores is
#
# tensor([[-0.7435, -1.0006, -1.8522],
#         [-1.1797, -0.6627, -1.7308],
#         [-1.2774, -0.9073, -1.1469],
#         [-1.2692, -0.7408, -1.4179],
#         [-1.1735, -0.7652, -1.4895]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9165611267089844
#
# tag_scores is
#
# tensor([[-1.1260, -0.8441, -1.4035],
#         [-1.3536, -0.8237, -1.1944],
#         [-0.9506, -0.8699, -1.6374],
#         [-1.3498, -0.6771, -1.4584]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9127447009086609
#
# tag_scores is
#
# tensor([[-0.7345, -1.0046, -1.8702],
#         [-1.1831, -0.6564, -1.7432],
#         [-1.2838, -0.9094, -1.1386],
#         [-1.2708, -0.7388, -1.4199],
#         [-1.1720, -0.7633, -1.4956]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9109247922897339
#
# tag_scores is
#
# tensor([[-1.1304, -0.8403, -1.4043],
#         [-1.3630, -0.8236, -1.1866],
#         [-0.9436, -0.8719, -1.6469],
#         [-1.3568, -0.6732, -1.4593]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9078983068466187
#
# tag_scores is
#
# tensor([[-0.7255, -1.0089, -1.8885],
#         [-1.1866, -0.6502, -1.7557],
#         [-1.2905, -0.9118, -1.1300],
#         [-1.2724, -0.7369, -1.4219],
#         [-1.1702, -0.7615, -1.5019]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.9051627516746521
#
# tag_scores is
#
# tensor([[-1.1351, -0.8365, -1.4049],
#         [-1.3727, -0.8237, -1.1783],
#         [-0.9366, -0.8741, -1.6565],
#         [-1.3639, -0.6692, -1.4600]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.9029358625411987
#
# tag_scores is
#
# tensor([[-0.7163, -1.0135, -1.9071],
#         [-1.1902, -0.6440, -1.7682],
#         [-1.2974, -0.9143, -1.1209],
#         [-1.2737, -0.7351, -1.4240],
#         [-1.1682, -0.7597, -1.5084]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8992725014686584
#
# tag_scores is
#
# tensor([[-1.1399, -0.8327, -1.4053],
#         [-1.3827, -0.8241, -1.1696],
#         [-0.9294, -0.8765, -1.6661],
#         [-1.3713, -0.6653, -1.4605]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8978557586669922
#
# tag_scores is
#
# tensor([[-0.7070, -1.0184, -1.9260],
#         [-1.1939, -0.6378, -1.7809],
#         [-1.3045, -0.9172, -1.1115],
#         [-1.2749, -0.7334, -1.4260],
#         [-1.1660, -0.7580, -1.5151]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8932520151138306
#
# tag_scores is
#
# tensor([[-1.1450, -0.8289, -1.4055],
#         [-1.3930, -0.8247, -1.1606],
#         [-0.9221, -0.8791, -1.6759],
#         [-1.3788, -0.6615, -1.4609]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.892656683921814
#
# tag_scores is
#
# tensor([[-0.6976, -1.0237, -1.9452],
#         [-1.1977, -0.6315, -1.7937],
#         [-1.3119, -0.9203, -1.1018],
#         [-1.2760, -0.7317, -1.4281],
#         [-1.1636, -0.7563, -1.5222]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8870992064476013
#
# tag_scores is
#
# tensor([[-1.1504, -0.8250, -1.4054],
#         [-1.4035, -0.8255, -1.1511],
#         [-0.9147, -0.8817, -1.6859],
#         [-1.3865, -0.6576, -1.4612]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8873375058174133
#
# tag_scores is
#
# tensor([[-0.6881, -1.0292, -1.9647],
#         [-1.2017, -0.6253, -1.8067],
#         [-1.3195, -0.9236, -1.0917],
#         [-1.2769, -0.7301, -1.4303],
#         [-1.1610, -0.7547, -1.5295]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8808122873306274
#
# tag_scores is
#
# tensor([[-1.1560, -0.8211, -1.4053],
#         [-1.4144, -0.8266, -1.1413],
#         [-0.9071, -0.8846, -1.6959],
#         [-1.3944, -0.6537, -1.4614]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8818972706794739
#
# tag_scores is
#
# tensor([[-0.6785, -1.0351, -1.9846],
#         [-1.2058, -0.6190, -1.8198],
#         [-1.3273, -0.9272, -1.0813],
#         [-1.2776, -0.7285, -1.4326],
#         [-1.1581, -0.7530, -1.5372]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8743897676467896
#
# tag_scores is
#
# tensor([[-1.1619, -0.8171, -1.4049],
#         [-1.4255, -0.8279, -1.1311],
#         [-0.8995, -0.8875, -1.7062],
#         [-1.4025, -0.6499, -1.4615]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8763353228569031
#
# tag_scores is
#
# tensor([[-0.6688, -1.0412, -2.0049],
#         [-1.2101, -0.6126, -1.8331],
#         [-1.3354, -0.9310, -1.0706],
#         [-1.2782, -0.7270, -1.4350],
#         [-1.1550, -0.7514, -1.5452]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8678303956985474
#
# tag_scores is
#
# tensor([[-1.1681, -0.8130, -1.4044],
#         [-1.4370, -0.8295, -1.1206],
#         [-0.8918, -0.8906, -1.7165],
#         [-1.4108, -0.6460, -1.4615]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8706516027450562
#
# tag_scores is
#
# tensor([[-0.6591, -1.0477, -2.0255],
#         [-1.2146, -0.6062, -1.8467],
#         [-1.3438, -0.9351, -1.0596],
#         [-1.2785, -0.7256, -1.4376],
#         [-1.1517, -0.7499, -1.5536]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8611329197883606
#
# tag_scores is
#
# tensor([[-1.1746, -0.8088, -1.4038],
#         [-1.4487, -0.8313, -1.1097],
#         [-0.8840, -0.8939, -1.7271],
#         [-1.4193, -0.6420, -1.4615]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8648457527160645
#
# tag_scores is
#
# tensor([[-0.6492, -1.0545, -2.0466],
#         [-1.2192, -0.5998, -1.8605],
#         [-1.3524, -0.9395, -1.0483],
#         [-1.2786, -0.7242, -1.4403],
#         [-1.1482, -0.7483, -1.5624]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8542962670326233
#
# tag_scores is
#
# tensor([[-1.1814, -0.8045, -1.4031],
#         [-1.4608, -0.8334, -1.0985],
#         [-0.8760, -0.8973, -1.7379],
#         [-1.4279, -0.6381, -1.4615]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8589183688163757
#
# tag_scores is
#
# tensor([[-0.6393, -1.0616, -2.0681],
#         [-1.2240, -0.5932, -1.8745],
#         [-1.3613, -0.9441, -1.0367],
#         [-1.2785, -0.7228, -1.4433],
#         [-1.1445, -0.7468, -1.5715]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8473198413848877
#
# tag_scores is
#
# tensor([[-1.1885, -0.8001, -1.4023],
#         [-1.4732, -0.8357, -1.0870],
#         [-0.8680, -0.9008, -1.7489],
#         [-1.4368, -0.6341, -1.4614]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8528698086738586
#
# tag_scores is
#
# tensor([[-0.6293, -1.0690, -2.0900],
#         [-1.2291, -0.5867, -1.8889],
#         [-1.3704, -0.9490, -1.0248],
#         [-1.2782, -0.7214, -1.4464],
#         [-1.1405, -0.7453, -1.5811]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.840203046798706
#
# tag_scores is
#
# tensor([[-1.1959, -0.7956, -1.4014],
#         [-1.4858, -0.8383, -1.0752],
#         [-0.8599, -0.9044, -1.7601],
#         [-1.4460, -0.6300, -1.4614]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8467011451721191
#
# tag_scores is
#
# tensor([[-0.6193, -1.0767, -2.1123],
#         [-1.2343, -0.5800, -1.9035],
#         [-1.3798, -0.9541, -1.0127],
#         [-1.2777, -0.7201, -1.4498],
#         [-1.1363, -0.7438, -1.5911]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8329452872276306
#
# tag_scores is
#
# tensor([[-1.2036, -0.7910, -1.4004],
#         [-1.4988, -0.8411, -1.0631],
#         [-0.8518, -0.9082, -1.7715],
#         [-1.4553, -0.6259, -1.4614]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8404136896133423
#
# tag_scores is
#
# tensor([[-0.6092, -1.0847, -2.1351],
#         [-1.2397, -0.5732, -1.9184],
#         [-1.3895, -0.9596, -1.0003],
#         [-1.2769, -0.7188, -1.4534],
#         [-1.1319, -0.7424, -1.6015]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8255466222763062
#
# tag_scores is
#
# tensor([[-1.2117, -0.7862, -1.3994],
#         [-1.5121, -0.8443, -1.0507],
#         [-0.8435, -0.9121, -1.7831],
#         [-1.4648, -0.6218, -1.4615]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8340088725090027
#
# tag_scores is
#
# tensor([[-0.5991, -1.0931, -2.1584],
#         [-1.2454, -0.5664, -1.9337],
#         [-1.3995, -0.9653, -0.9877],
#         [-1.2759, -0.7176, -1.4573],
#         [-1.1274, -0.7409, -1.6123]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8180068135261536
#
# tag_scores is
#
# tensor([[-1.2201, -0.7813, -1.3984],
#         [-1.5257, -0.8478, -1.0380],
#         [-0.8352, -0.9161, -1.7950],
#         [-1.4746, -0.6176, -1.4616]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8274887204170227
#
# tag_scores is
#
# tensor([[-0.5890, -1.1017, -2.1821],
#         [-1.2513, -0.5595, -1.9493],
#         [-1.4098, -0.9714, -0.9749],
#         [-1.2746, -0.7163, -1.4614],
#         [-1.1226, -0.7395, -1.6235]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8103262186050415
# tag_scores is
#
# tensor([[-1.2289, -0.7762, -1.3973],
#         [-1.5396, -0.8515, -1.0251],
#         [-0.8268, -0.9203, -1.8071],
#         [-1.4845, -0.6133, -1.4618]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8208552598953247
#
# tag_scores is
#
# tensor([[-0.5789, -1.1106, -2.2062],
#         [-1.2574, -0.5525, -1.9653],
#         [-1.4204, -0.9777, -0.9618],
#         [-1.2730, -0.7151, -1.4658],
#         [-1.1176, -0.7381, -1.6351]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.8025050759315491
#
# tag_scores is
#
# tensor([[-1.2380, -0.7710, -1.3963],
#         [-1.5538, -0.8556, -1.0119],
#         [-0.8183, -0.9246, -1.8195],
#         [-1.4947, -0.6089, -1.4622]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.814111053943634
#
# tag_scores is
#
# tensor([[-0.5687, -1.1199, -2.2309],
#         [-1.2639, -0.5454, -1.9816],
#         [-1.4312, -0.9844, -0.9485],
#         [-1.2712, -0.7140, -1.4705],
#         [-1.1125, -0.7367, -1.6472]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7945440411567688
#
# tag_scores is
#
# tensor([[-1.2475, -0.7656, -1.3954],
#         [-1.5682, -0.8601, -0.9984],
#         [-0.8097, -0.9290, -1.8321],
#         [-1.5051, -0.6044, -1.4627]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8072589039802551
#
# tag_scores is
#
# tensor([[-0.5586, -1.1294, -2.2561],
#         [-1.2705, -0.5383, -1.9984],
#         [-1.4424, -0.9914, -0.9350],
#         [-1.2691, -0.7129, -1.4755],
#         [-1.1072, -0.7354, -1.6597]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.786443829536438
#
# tag_scores is
#
# tensor([[-1.2574, -0.7600, -1.3945],
#         [-1.5830, -0.8648, -0.9848],
#         [-0.8011, -0.9336, -1.8450],
#         [-1.5158, -0.5998, -1.4633]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.8003019094467163
#
# tag_scores is
#
# tensor([[-0.5485, -1.1393, -2.2817],
#         [-1.2775, -0.5310, -2.0156],
#         [-1.4538, -0.9987, -0.9213],
#         [-1.2667, -0.7118, -1.4808],
#         [-1.1018, -0.7341, -1.6726]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7782052755355835
#
# tag_scores is
#
# tensor([[-1.2676, -0.7543, -1.3937],
#         [-1.5981, -0.8699, -0.9709],
#         [-0.7924, -0.9383, -1.8581],
#         [-1.5266, -0.5952, -1.4642]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7932432293891907
#
# tag_scores is
#
# tensor([[-0.5383, -1.1495, -2.3078],
#         [-1.2847, -0.5236, -2.0332],
#         [-1.4656, -1.0064, -0.9075],
#         [-1.2640, -0.7107, -1.4864],
#         [-1.0962, -0.7328, -1.6858]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7698298692703247
#
# tag_scores is
#
# tensor([[-1.2782, -0.7484, -1.3931],
#         [-1.6134, -0.8754, -0.9569],
#         [-0.7837, -0.9432, -1.8716],
#         [-1.5377, -0.5904, -1.4652]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7860864996910095
#
# tag_scores is
#
# tensor([[-0.5283, -1.1599, -2.3344],
#         [-1.2923, -0.5162, -2.0513],
#         [-1.4776, -1.0145, -0.8934],
#         [-1.2610, -0.7097, -1.4923],
#         [-1.0905, -0.7315, -1.6995]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7613186836242676
#
# tag_scores is
#
# tensor([[-1.2891, -0.7422, -1.3926],
#         [-1.6290, -0.8812, -0.9426],
#         [-0.7749, -0.9482, -1.8853],
#         [-1.5490, -0.5855, -1.4665]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7788355350494385
#
# tag_scores is
#
# tensor([[-0.5182, -1.1707, -2.3615],
#         [-1.3001, -0.5086, -2.0699],
#         [-1.4900, -1.0229, -0.8793],
#         [-1.2577, -0.7088, -1.4986],
#         [-1.0847, -0.7303, -1.7135]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7526735067367554
#
# tag_scores is
#
# tensor([[-1.3004, -0.7359, -1.3923],
#         [-1.6449, -0.8875, -0.9282],
#         [-0.7660, -0.9533, -1.8992],
#         [-1.5605, -0.5806, -1.4680]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7714942097663879
#
# tag_scores is
#
# tensor([[-0.5083, -1.1817, -2.3891],
#         [-1.3083, -0.5010, -2.0889],
#         [-1.5027, -1.0318, -0.8649],
#         [-1.2541, -0.7079, -1.5052],
#         [-1.0788, -0.7291, -1.7279]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7438960671424866
#
# tag_scores is
#
# tensor([[-1.3121, -0.7294, -1.3922],
#         [-1.6610, -0.8941, -0.9136],
#         [-0.7571, -0.9586, -1.9135],
#         [-1.5722, -0.5754, -1.4699]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7640666961669922
#
# tag_scores is
#
# tensor([[-0.4983, -1.1931, -2.4172],
#         [-1.3169, -0.4933, -2.1085],
#         [-1.5156, -1.0410, -0.8504],
#         [-1.2503, -0.7070, -1.5121],
#         [-1.0728, -0.7280, -1.7426]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7349887490272522
#
# tag_scores is
#
# tensor([[-1.3242, -0.7226, -1.3923],
#         [-1.6774, -0.9011, -0.8989],
#         [-0.7482, -0.9640, -1.9281],
#         [-1.5842, -0.5702, -1.4720]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7565573453903198
#
# tag_scores is
#
# tensor([[-0.4885, -1.2047, -2.4458],
#         [-1.3257, -0.4855, -2.1285],
#         [-1.5289, -1.0506, -0.8358],
#         [-1.2461, -0.7062, -1.5193],
#         [-1.0667, -0.7269, -1.7577]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7259540557861328
#
# tag_scores is
#
# tensor([[-1.3366, -0.7157, -1.3928],
#         [-1.6940, -0.9085, -0.8841],
#         [-0.7392, -0.9696, -1.9429],
#         [-1.5964, -0.5648, -1.4744]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7489705085754395
#
# tag_scores is
#
# tensor([[-0.4787, -1.2166, -2.4748],
#         [-1.3349, -0.4776, -2.1491],
#         [-1.5425, -1.0607, -0.8211],
#         [-1.2416, -0.7055, -1.5269],
#         [-1.0605, -0.7258, -1.7731]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7167944312095642
#
# tag_scores is
#
# tensor([[-1.3493, -0.7085, -1.3935],
#         [-1.7109, -0.9163, -0.8692],
#         [-0.7302, -0.9753, -1.9581],
#         [-1.6088, -0.5593, -1.4772]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7413108944892883
#
# tag_scores is
#
# tensor([[-0.4690, -1.2288, -2.5044],
#         [-1.3445, -0.4697, -2.1702],
#         [-1.5563, -1.0712, -0.8063],
#         [-1.2368, -0.7048, -1.5348],
#         [-1.0544, -0.7248, -1.7889]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.7075133919715881
#
# tag_scores is
#
# tensor([[-1.3625, -0.7011, -1.3946],
#         [-1.7280, -0.9246, -0.8541],
#         [-0.7212, -0.9812, -1.9735],
#         [-1.6214, -0.5537, -1.4804]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7335832715034485
#
# tag_scores is
#
# tensor([[-0.4594, -1.2413, -2.5344],
#         [-1.3545, -0.4617, -2.1919],
#         [-1.5705, -1.0822, -0.7914],
#         [-1.2317, -0.7043, -1.5431],
#         [-1.0481, -0.7237, -1.8050]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6981143355369568
#
# tag_scores is
#
# tensor([[-1.3760, -0.6935, -1.3960],
#         [-1.7453, -0.9333, -0.8390],
#         [-0.7121, -0.9873, -1.9892],
#         [-1.6343, -0.5479, -1.4840]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7257923483848572
#
# tag_scores is
#
# tensor([[-0.4499, -1.2540, -2.5649],
#         [-1.3649, -0.4536, -2.2141],
#         [-1.5850, -1.0936, -0.7765],
#         [-1.2263, -0.7038, -1.5516],
#         [-1.0419, -0.7227, -1.8214]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6886012554168701
#
# tag_scores is
#
# tensor([[-1.3898, -0.6857, -1.3979],
#         [-1.7628, -0.9424, -0.8238],
#         [-0.7030, -0.9935, -2.0053],
#         [-1.6474, -0.5419, -1.4880]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.717943012714386
#
# tag_scores is
#
# tensor([[-0.4405, -1.2670, -2.5958],
#         [-1.3756, -0.4455, -2.2369],
#         [-1.5998, -1.1054, -0.7614],
#         [-1.2206, -0.7034, -1.5606],
#         [-1.0357, -0.7218, -1.8381]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.678978681564331
#
# tag_scores is
#
# tensor([[-1.4040, -0.6776, -1.4002],
#         [-1.7806, -0.9520, -0.8086],
#         [-0.6939, -0.9999, -2.0216],
#         [-1.6607, -0.5358, -1.4925]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7100402116775513
#
# tag_scores is
#
# tensor([[-0.4312, -1.2802, -2.6271],
#         [-1.3867, -0.4373, -2.2603],
#         [-1.6148, -1.1178, -0.7464],
#         [-1.2145, -0.7031, -1.5698],
#         [-1.0295, -0.7208, -1.8550]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6692515015602112
#
# tag_scores is
#
# tensor([[-1.4186, -0.6693, -1.4029],
#         [-1.7985, -0.9620, -0.7934],
#         [-0.6847, -1.0064, -2.0382],
#         [-1.6743, -0.5296, -1.4974]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.7020889520645142
#
# tag_scores is
#
# tensor([[-0.4220, -1.2937, -2.6589],
#         [-1.3983, -0.4290, -2.2842],
#         [-1.6302, -1.1306, -0.7313],
#         [-1.2082, -0.7029, -1.5794],
#         [-1.0233, -0.7198, -1.8723]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6594250202178955
#
# tag_scores is
#
# tensor([[-1.4335, -0.6608, -1.4062],
#         [-1.8166, -0.9724, -0.7781],
#         [-0.6756, -1.0132, -2.0552],
#         [-1.6881, -0.5232, -1.5028]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6940944194793701
#
# tag_scores is
#
# tensor([[-0.4130, -1.3074, -2.6911],
#         [-1.4103, -0.4208, -2.3087],
#         [-1.6459, -1.1440, -0.7162],
#         [-1.2016, -0.7028, -1.5893],
#         [-1.0172, -0.7189, -1.8899]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.649505615234375
#
# tag_scores is
#
# tensor([[-1.4487, -0.6521, -1.4100],
#         [-1.8349, -0.9834, -0.7629],
#         [-0.6664, -1.0201, -2.0724],
#         [-1.7021, -0.5167, -1.5087]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6860615015029907
#
# tag_scores is
#
# tensor([[-0.4041, -1.3213, -2.7237],
#         [-1.4226, -0.4125, -2.3338],
#         [-1.6618, -1.1578, -0.7011],
#         [-1.1947, -0.7028, -1.5995],
#         [-1.0111, -0.7179, -1.9077]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6394994854927063
#
# tag_scores is
#
# tensor([[-1.4643, -0.6431, -1.4143],
#         [-1.8534, -0.9948, -0.7476],
#         [-0.6573, -1.0272, -2.0899],
#         [-1.7163, -0.5100, -1.5152]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6779953241348267
#
# tag_scores is
#
# tensor([[-0.3953, -1.3355, -2.7567],
#         [-1.4354, -0.4042, -2.3595],
#         [-1.6780, -1.1722, -0.6860],
#         [-1.1875, -0.7029, -1.6100],
#         [-1.0051, -0.7170, -1.9259]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6294139623641968
#
# tag_scores is
#
# tensor([[-1.4802, -0.6340, -1.4192],
#         [-1.8720, -1.0066, -0.7325],
#         [-0.6481, -1.0344, -2.1077],
#         [-1.7308, -0.5032, -1.5222]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6699008345603943
#
# tag_scores is
#
# tensor([[-0.3867, -1.3499, -2.7901],
#         [-1.4486, -0.3959, -2.3857],
#         [-1.6946, -1.1870, -0.6710],
#         [-1.1800, -0.7032, -1.6209],
#         [-0.9992, -0.7160, -1.9443]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6192567348480225
#
# tag_scores is
#
# tensor([[-1.4964, -0.6246, -1.4247],
#         [-1.8908, -1.0189, -0.7173],
#         [-0.6389, -1.0419, -2.1257],
#         [-1.7455, -0.4962, -1.5297]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6617833375930786
#
# tag_scores is
#
# tensor([[-0.3782, -1.3645, -2.8238],
#         [-1.4623, -0.3876, -2.4125],
#         [-1.7113, -1.2024, -0.6560],
#         [-1.1722, -0.7036, -1.6320],
#         [-0.9933, -0.7149, -1.9630]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.6090362071990967
#
# tag_scores is
#
# tensor([[-1.5129, -0.6151, -1.4308],
#         [-1.9098, -1.0317, -0.7022],
#         [-0.6297, -1.0496, -2.1441],
#         [-1.7604, -0.4891, -1.5378]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6536475419998169
#
# tag_scores is
#
# tensor([[-0.3698, -1.3793, -2.8579],
#         [-1.4763, -0.3793, -2.4398],
#         [-1.7284, -1.2183, -0.6411],
#         [-1.1641, -0.7042, -1.6434],
#         [-0.9876, -0.7139, -1.9820]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5987610816955566
#
# tag_scores is
#
# tensor([[-1.5298, -0.6053, -1.4375],
#         [-1.9289, -1.0449, -0.6872],
#         [-0.6206, -1.0574, -2.1627],
#         [-1.7756, -0.4819, -1.5464]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6454983949661255
#
# tag_scores is
#
# tensor([[-0.3617, -1.3942, -2.8923],
#         [-1.4908, -0.3710, -2.4677],
#         [-1.7457, -1.2348, -0.6263],
#         [-1.1558, -0.7049, -1.6552],
#         [-0.9821, -0.7127, -2.0012]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5884408950805664
#
# tag_scores is
#
# tensor([[-1.5470, -0.5954, -1.4449],
#         [-1.9481, -1.0586, -0.6723],
#         [-0.6114, -1.0655, -2.1816],
#         [-1.7909, -0.4746, -1.5556]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6373411417007446
#
# tag_scores is
#
# tensor([[-0.3536, -1.4094, -2.9269],
#         [-1.5056, -0.3628, -2.4961],
#         [-1.7633, -1.2517, -0.6115],
#         [-1.1472, -0.7058, -1.6672],
#         [-0.9767, -0.7115, -2.0208]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5780853629112244
#
# tag_scores is
#
# tensor([[-1.5644, -0.5854, -1.4529],
#         [-1.9675, -1.0727, -0.6575],
#         [-0.6023, -1.0738, -2.2008],
#         [-1.8065, -0.4672, -1.5654]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6291802525520325
#
# tag_scores is
#
# tensor([[-0.3457, -1.4247, -2.9619],
#         [-1.5209, -0.3546, -2.5251],
#         [-1.7812, -1.2692, -0.5969],
#         [-1.1383, -0.7069, -1.6795],
#         [-0.9714, -0.7103, -2.0406]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5677049160003662
#
# tag_scores is
#
# tensor([[-1.5822, -0.5752, -1.4616],
#         [-1.9870, -1.0873, -0.6429],
#         [-0.5931, -1.0823, -2.2202],
#         [-1.8223, -0.4597, -1.5757]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6210206151008606
#
# tag_scores is
#
# tensor([[-0.3380, -1.4402, -2.9971],
#         [-1.5366, -0.3465, -2.5545],
#         [-1.7993, -1.2872, -0.5824],
#         [-1.1292, -0.7081, -1.6921],
#         [-0.9663, -0.7089, -2.0608]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5573102235794067
#
# tag_scores is
#
# tensor([[-1.6003, -0.5648, -1.4710],
#         [-2.0066, -1.1024, -0.6283],
#         [-0.5840, -1.0910, -2.2399],
#         [-1.8384, -0.4521, -1.5867]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6128668785095215
#
# tag_scores is
#
# tensor([[-0.3304, -1.4558, -3.0325],
#         [-1.5527, -0.3385, -2.5843],
#         [-1.8177, -1.3057, -0.5681],
#         [-1.1199, -0.7095, -1.7049],
#         [-0.9615, -0.7075, -2.0812]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5469123721122742
#
# tag_scores is
#
# tensor([[-1.6187, -0.5544, -1.4810],
#         [-2.0264, -1.1179, -0.6140],
#         [-0.5749, -1.1000, -2.2598],
#         [-1.8546, -0.4444, -1.5982]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.6047237515449524
#
# tag_scores is
#
# tensor([[-0.3230, -1.4716, -3.0682],
#         [-1.5691, -0.3305, -2.6146],
#         [-1.8363, -1.3246, -0.5539],
#         [-1.1103, -0.7111, -1.7179],
#         [-0.9568, -0.7059, -2.1019]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5365225076675415
#
# tag_scores is
#
# tensor([[-1.6373, -0.5438, -1.4917],
#         [-2.0462, -1.1338, -0.5997],
#         [-0.5659, -1.1092, -2.2800],
#         [-1.8710, -0.4367, -1.6102]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5965956449508667
#
# tag_scores is
#
# tensor([[-0.3158, -1.4876, -3.1040],
#         [-1.5859, -0.3226, -2.6453],
#         [-1.8551, -1.3441, -0.5399],
#         [-1.1004, -0.7129, -1.7312],
#         [-0.9523, -0.7042, -2.1229]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5261520147323608
#
# tag_scores is
#
# tensor([[-1.6563, -0.5332, -1.5031],
#         [-2.0662, -1.1501, -0.5857],
#         [-0.5568, -1.1186, -2.3004],
#         [-1.8876, -0.4289, -1.6228]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5884871482849121
#
# tag_scores is
#
# tensor([[-0.3087, -1.5037, -3.1400],
#         [-1.6031, -0.3148, -2.6765],
#         [-1.8742, -1.3640, -0.5261],
#         [-1.0904, -0.7149, -1.7448],
#         [-0.9481, -0.7024, -2.1443]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5158124566078186
#
# tag_scores is
#
# tensor([[-1.6755, -0.5225, -1.5152],
#         [-2.0862, -1.1669, -0.5718],
#         [-0.5478, -1.1282, -2.3210],
#         [-1.9044, -0.4211, -1.6359]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5804025530815125
#
# tag_scores is
#
# tensor([[-0.3018, -1.5199, -3.1761],
#         [-1.6206, -0.3071, -2.7079],
#         [-1.8935, -1.3844, -0.5125],
#         [-1.0801, -0.7171, -1.7585],
#         [-0.9442, -0.7005, -2.1659]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.5055151581764221
#
# tag_scores is
#
# tensor([[-1.6950, -0.5118, -1.5279],
#         [-2.1064, -1.1841, -0.5581],
#         [-0.5388, -1.1381, -2.3418],
#         [-1.9214, -0.4133, -1.6496]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5723462700843811
#
# tag_scores is
#
# tensor([[-0.2950, -1.5362, -3.2124],
#         [-1.6385, -0.2996, -2.7397],
#         [-1.9130, -1.4052, -0.4991],
#         [-1.0697, -0.7196, -1.7725],
#         [-0.9405, -0.6984, -2.1879]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.49527156352996826
#
# tag_scores is
#
# tensor([[-1.7147, -0.5011, -1.5412],
#         [-2.1266, -1.2016, -0.5446],
#         [-0.5299, -1.1483, -2.3629],
#         [-1.9386, -0.4055, -1.6638]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5643225908279419
#
# tag_scores is
#
# tensor([[-0.2884, -1.5526, -3.2487],
#         [-1.6567, -0.2921, -2.7718],
#         [-1.9327, -1.4264, -0.4860],
#         [-1.0590, -0.7222, -1.7866],
#         [-0.9370, -0.6961, -2.2101]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.48509272933006287
#
# tag_scores is
#
# tensor([[-1.7347, -0.4904, -1.5552],
#         [-2.1469, -1.2196, -0.5314],
#         [-0.5210, -1.1587, -2.3841],
#         [-1.9559, -0.3977, -1.6784]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5563355684280396
#
# tag_scores is
#
# tensor([[-0.2819, -1.5691, -3.2851],
#         [-1.6752, -0.2848, -2.8041],
#         [-1.9527, -1.4481, -0.4731],
#         [-1.0482, -0.7251, -1.8009],
#         [-0.9339, -0.6937, -2.2327]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.4749895930290222
#
# tag_scores is
#
# tensor([[-1.7550, -0.4796, -1.5698],
#         [-2.1673, -1.2379, -0.5183],
#         [-0.5122, -1.1693, -2.4055],
#         [-1.9734, -0.3899, -1.6935]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5483894944190979
#
# tag_scores is
#
# tensor([[-0.2756, -1.5858, -3.3216],
#         [-1.6940, -0.2776, -2.8367],
#         [-1.9728, -1.4700, -0.4604],
#         [-1.0373, -0.7281, -1.8154],
#         [-0.9311, -0.6911, -2.2555]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.46497246623039246
#
# tag_scores is
#
# tensor([[-1.7755, -0.4690, -1.5850],
#         [-2.1878, -1.2566, -0.5055],
#         [-0.5033, -1.1802, -2.4271],
#         [-1.9911, -0.3821, -1.7091]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5404884219169617
#
# tag_scores is
#
# tensor([[-0.2694, -1.6025, -3.3580],
#         [-1.7131, -0.2705, -2.8695],
#         [-1.9931, -1.4924, -0.4480],
#         [-1.0262, -0.7314, -1.8301],
#         [-0.9285, -0.6883, -2.2787]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.4550516605377197
#
# tag_scores is
#
# tensor([[-1.7962, -0.4584, -1.6007],
#         [-2.2083, -1.2757, -0.4929],
#         [-0.4946, -1.1914, -2.4489],
#         [-2.0089, -0.3744, -1.7251]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5326365232467651
#
# tag_scores is
#
# tensor([[-0.2634, -1.6193, -3.3945],
#         [-1.7325, -0.2636, -2.9024],
#         [-2.0135, -1.5150, -0.4359],
#         [-1.0149, -0.7350, -1.8449],
#         [-0.9263, -0.6853, -2.3021]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.44523656368255615
#
# tag_scores is
#
# tensor([[-1.8172, -0.4478, -1.6170],
#         [-2.2289, -1.2950, -0.4805],
#         [-0.4859, -1.2029, -2.4708],
#         [-2.0268, -0.3667, -1.7415]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5248375535011292
#
# tag_scores is
#
# tensor([[-0.2576, -1.6362, -3.4310],
#         [-1.7522, -0.2568, -2.9355],
#         [-2.0342, -1.5379, -0.4241],
#         [-1.0035, -0.7387, -1.8598],
#         [-0.9244, -0.6822, -2.3257]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.43553626537323
#
# tag_scores is
#
# tensor([[-1.8384, -0.4373, -1.6338],
#         [-2.2496, -1.3147, -0.4684],
#         [-0.4772, -1.2146, -2.4929],
#         [-2.0449, -0.3591, -1.7583]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.5170955061912537
#
# tag_scores is
#
# tensor([[-0.2519, -1.6532, -3.4674],
#         [-1.7721, -0.2502, -2.9686],
# ...
#         [-3.1104, -0.0549, -4.7247]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03265870735049248
#
# tag_scores is
#
# tensor([[-4.6312, -0.0279, -4.0320],
#         [-4.7393, -3.3640, -0.0443],
#         [-0.0255, -3.9268, -5.2091],
#         [-4.4317, -0.0330, -3.8858]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03710523992776871
#
# tag_scores is
#
# tensor([[-0.0247, -3.7628, -6.7147],
#         [-4.7251, -0.0124, -5.6799],
#         [-4.7273, -3.6594, -0.0352],
#         [-0.0587, -3.2618, -3.9776],
#         [-3.1191, -0.0545, -4.7301]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03244129568338394
#
# tag_scores is
#
# tensor([[-4.6383, -0.0277, -4.0386],
#         [-4.7464, -3.3693, -0.0441],
#         [-0.0253, -3.9351, -5.2162],
#         [-4.4392, -0.0327, -3.8916]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03681304305791855
#
# tag_scores is
#
# tensor([[-0.0246, -3.7686, -6.7223],
#         [-4.7335, -0.0123, -5.6853],
#         [-4.7349, -3.6645, -0.0350],
#         [-0.0582, -3.2719, -3.9856],
#         [-3.1277, -0.0540, -4.7354]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03222658112645149
#
# tag_scores is
#
# tensor([[-4.6454, -0.0275, -4.0452],
#         [-4.7536, -3.3745, -0.0438],
#         [-0.0251, -3.9434, -5.2232],
#         [-4.4467, -0.0325, -3.8974]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.036524973809719086
#
# tag_scores is
#
# tensor([[-0.0244, -3.7743, -6.7298],
#         [-4.7418, -0.0122, -5.6908],
#         [-4.7424, -3.6697, -0.0348],
#         [-0.0576, -3.2819, -3.9936],
#         [-3.1363, -0.0536, -4.7406]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03201453760266304
#
# tag_scores is
#
# tensor([[-4.6524, -0.0273, -4.0518],
#         [-4.7607, -3.3798, -0.0435],
#         [-0.0249, -3.9516, -5.2302],
#         [-4.4541, -0.0323, -3.9031]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03624098375439644
#
# tag_scores is
#
# tensor([[-0.0243, -3.7800, -6.7373],
#         [-4.7501, -0.0121, -5.6962],
#         [-4.7499, -3.6748, -0.0346],
#         [-0.0571, -3.2918, -4.0015],
#         [-3.1448, -0.0532, -4.7459]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.031805094331502914
#
# tag_scores is
#
# tensor([[-4.6594, -0.0271, -4.0583],
#         [-4.7678, -3.3850, -0.0433],
#         [-0.0247, -3.9598, -5.2371],
#         [-4.4614, -0.0321, -3.9088]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03596099838614464
#
# tag_scores is
#
# tensor([[-0.0242, -3.7857, -6.7447],
#         [-4.7584, -0.0120, -5.7015],
#         [-4.7573, -3.6798, -0.0344],
#         [-0.0565, -3.3017, -4.0094],
#         [-3.1533, -0.0527, -4.7511]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03159821406006813
#
# tag_scores is
#
# tensor([[-4.6663, -0.0269, -4.0648],
#         [-4.7748, -3.3902, -0.0431],
#         [-0.0245, -3.9679, -5.2440],
#         [-4.4687, -0.0319, -3.9145]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.035684891045093536
#
# tag_scores is
#
# tensor([[-0.0240, -3.7913, -6.7521],
#         [-4.7666, -0.0119, -5.7069],
#         [-4.7647, -3.6849, -0.0342],
#         [-0.0560, -3.3116, -4.0172],
#         [-3.1617, -0.0523, -4.7562]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
# loss is
#
# 0.0313938669860363
#
# tag_scores is
#
# tensor([[-4.6732, -0.0268, -4.0713],
#         [-4.7818, -3.3954, -0.0428],
#         [-0.0243, -3.9760, -5.2509],
#         [-4.4760, -0.0317, -3.9201]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03541264310479164
#
# tag_scores is
#
# tensor([[-0.0239, -3.7969, -6.7594],
#         [-4.7747, -0.0118, -5.7122],
#         [-4.7720, -3.6899, -0.0340],
#         [-0.0555, -3.3213, -4.0251],
#         [-3.1701, -0.0519, -4.7613]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.031191986054182053
#
# tag_scores is
#
# tensor([[-4.6800, -0.0266, -4.0777],
#         [-4.7887, -3.4005, -0.0426],
#         [-0.0241, -3.9840, -5.2577],
#         [-4.4833, -0.0315, -3.9257]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03514414280653
#
# tag_scores is
#
# tensor([[-0.0237, -3.8024, -6.7667],
#         [-4.7828, -0.0117, -5.7174],
#         [-4.7793, -3.6949, -0.0338],
#         [-0.0550, -3.3310, -4.0328],
#         [-3.1784, -0.0515, -4.7664]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.030992552638053894
#
# tag_scores is
#
# tensor([[-4.6868, -0.0264, -4.0841],
#         [-4.7956, -3.4057, -0.0423],
#         [-0.0239, -3.9920, -5.2645],
#         [-4.4905, -0.0313, -3.9313]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03487931936979294
#
# tag_scores is
#
# tensor([[-0.0236, -3.8080, -6.7740],
#         [-4.7908, -0.0116, -5.7227],
#         [-4.7866, -3.6999, -0.0336],
#         [-0.0545, -3.3407, -4.0406],
#         [-3.1867, -0.0511, -4.7715]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.030795477330684662
#
# tag_scores is
#
# tensor([[-4.6936, -0.0262, -4.0905],
#         [-4.8025, -3.4108, -0.0421],
#         [-0.0237, -3.9999, -5.2712],
#         [-4.4976, -0.0311, -3.9369]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03461812064051628
#
# tag_scores is
#
# tensor([[-0.0235, -3.8134, -6.7812],
#         [-4.7988, -0.0116, -5.7279],
#         [-4.7938, -3.7048, -0.0334],
#         [-0.0540, -3.3503, -4.0483],
#         [-3.1949, -0.0507, -4.7765]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.030600767582654953
#
# tag_scores is
#
# tensor([[-4.7003, -0.0261, -4.0968],
#         [-4.8093, -3.4159, -0.0419],
#         [-0.0236, -4.0078, -5.2779],
#         [-4.5048, -0.0309, -3.9424]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03436047211289406
#
# tag_scores is
#
# tensor([[-0.0233, -3.8189, -6.7883],
#         [-4.8067, -0.0115, -5.7331],
#         [-4.8010, -3.7098, -0.0333],
#         [-0.0535, -3.3598, -4.0560],
#         [-3.2031, -0.0503, -4.7815]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.030408363789319992
#
# tag_scores is
#
# tensor([[-4.7069, -0.0259, -4.1031],
#         [-4.8161, -3.4209, -0.0416],
#         [-0.0234, -4.0156, -5.2845],
#         [-4.5119, -0.0307, -3.9479]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.034106284379959106
#
# tag_scores is
#
# tensor([[-0.0232, -3.8243, -6.7955],
#         [-4.8146, -0.0114, -5.7382],
#         [-4.8081, -3.7147, -0.0331],
#         [-0.0530, -3.3693, -4.0636],
#         [-3.2113, -0.0499, -4.7864]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.030218223109841347
#
# tag_scores is
#
# tensor([[-4.7135, -0.0257, -4.1094],
#         [-4.8229, -3.4260, -0.0414],
#         [-0.0232, -4.0234, -5.2911],
#         [-4.5189, -0.0306, -3.9534]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03385552018880844
#
# tag_scores is
#
# tensor([[-0.0231, -3.8297, -6.8025],
#         [-4.8224, -0.0113, -5.7434],
#         [-4.8152, -3.7196, -0.0329],
#         [-0.0525, -3.3787, -4.0712],
#         [-3.2194, -0.0495, -4.7914]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.03003031015396118
#
# tag_scores is
#
# tensor([[-4.7201, -0.0256, -4.1157],
#         [-4.8296, -3.4310, -0.0412],
#         [-0.0230, -4.0312, -5.2977],
#         [-4.5259, -0.0304, -3.9588]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.0336080901324749
#
# tag_scores is
#
# tensor([[-0.0230, -3.8351, -6.8096],
#         [-4.8302, -0.0112, -5.7485],
#         [-4.8223, -3.7245, -0.0327],
#         [-0.0520, -3.3881, -4.0788],
#         [-3.2274, -0.0491, -4.7962]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.029844585806131363
#
# tag_scores is
#
# tensor([[-4.7267, -0.0254, -4.1219],
#         [-4.8363, -3.4360, -0.0410],
#         [-0.0228, -4.0389, -5.3042],
#         [-4.5329, -0.0302, -3.9642]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.0333639457821846
#
# tag_scores is
#
# tensor([[-0.0228, -3.8404, -6.8166],
#         [-4.8379, -0.0112, -5.7535],
#         [-4.8293, -3.7293, -0.0325],
#         [-0.0516, -3.3974, -4.0863],
#         [-3.2354, -0.0487, -4.8011]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.029661022126674652
#
# tag_scores is
#
# tensor([[-4.7331, -0.0252, -4.1280],
#         [-4.8430, -3.4409, -0.0407],
#         [-0.0227, -4.0465, -5.3107],
#         [-4.5398, -0.0300, -3.9696]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03312302753329277
#
# tag_scores is
#
# tensor([[-0.0227, -3.8457, -6.8235],
#         [-4.8456, -0.0111, -5.7586],
#         [-4.8363, -3.7341, -0.0323],
#         [-0.0511, -3.4067, -4.0938],
#         [-3.2434, -0.0484, -4.8059]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.02947956696152687
#
# tag_scores is
#
# tensor([[-4.7396, -0.0251, -4.1342],
#         [-4.8496, -3.4459, -0.0405],
#         [-0.0225, -4.0541, -5.3172],
#         [-4.5467, -0.0298, -3.9750]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03288526087999344
#
# tag_scores is
#
# tensor([[-0.0226, -3.8510, -6.8304],
#         [-4.8533, -0.0110, -5.7636],
#         [-4.8432, -3.7389, -0.0322],
#         [-0.0507, -3.4159, -4.1012],
#         [-3.2513, -0.0480, -4.8107]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.02930019423365593
#
# tag_scores is
#
# tensor([[-4.7460, -0.0249, -4.1403],
#         [-4.8562, -3.4508, -0.0403],
#         [-0.0223, -4.0617, -5.3236],
#         [-4.5536, -0.0296, -3.9803]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03265061229467392
#
# tag_scores is
#
# tensor([[-0.0225, -3.8563, -6.8373],
#         [-4.8609, -0.0109, -5.7686],
#         [-4.8501, -3.7437, -0.0320],
#         [-0.0502, -3.4251, -4.1087],
#         [-3.2592, -0.0476, -4.8155]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.029122870415449142
#
# tag_scores is
#
# tensor([[-4.7524, -0.0248, -4.1464],
#         [-4.8628, -3.4557, -0.0401],
#         [-0.0222, -4.0692, -5.3300],
#         [-4.5604, -0.0295, -3.9856]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03241899609565735
#
# tag_scores is
#
# tensor([[-0.0224, -3.8615, -6.8441],
#         [-4.8684, -0.0109, -5.7735],
#         [-4.8569, -3.7485, -0.0318],
#         [-0.0498, -3.4342, -4.1161],
#         [-3.2670, -0.0473, -4.8202]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.02894754894077778
#
# tag_scores is
#
# tensor([[-4.7587, -0.0246, -4.1525],
#         [-4.8693, -3.4606, -0.0399],
#         [-0.0220, -4.0767, -5.3363],
#         [-4.5672, -0.0293, -3.9909]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03219037503004074
#
# tag_scores is
#
# tensor([[-0.0222, -3.8667, -6.8509],
#         [-4.8759, -0.0108, -5.7785],
#         [-4.8638, -3.7532, -0.0317],
#         [-0.0493, -3.4433, -4.1234],
#         [-3.2748, -0.0469, -4.8249]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.028774216771125793
#
# tag_scores is
#
# tensor([[-4.7650, -0.0245, -4.1585],
#         [-4.8758, -3.4654, -0.0397],
#         [-0.0219, -4.0841, -5.3426],
#         [-4.5740, -0.0291, -3.9962]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03196469321846962
#
# tag_scores is
#
# tensor([[-0.0221, -3.8718, -6.8576],
#         [-4.8834, -0.0107, -5.7834],
#         [-4.8706, -3.7579, -0.0315],
#         [-0.0489, -3.4523, -4.1307],
#         [-3.2826, -0.0466, -4.8296]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.028602825477719307
#
# tag_scores is
#
# tensor([[-4.7713, -0.0243, -4.1645],
#         [-4.8822, -3.4703, -0.0395],
#         [-0.0217, -4.0915, -5.3489],
#         [-4.5807, -0.0290, -4.0014]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03174188360571861
#
# tag_scores is
#
# tensor([[-0.0220, -3.8770, -6.8643],
#         [-4.8908, -0.0106, -5.7883],
#         [-4.8773, -3.7626, -0.0313],
#         [-0.0485, -3.4613, -4.1380],
#         [-3.2903, -0.0462, -4.8342]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.028433354571461678
#
# tag_scores is
#
# tensor([[-4.7775, -0.0242, -4.1705],
#         [-4.8887, -3.4751, -0.0393],
#         [-0.0215, -4.0988, -5.3551],
#         [-4.5874, -0.0288, -4.0066]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03152192384004593
#
# tag_scores is
#
# tensor([[-0.0219, -3.8821, -6.8710],
#         [-4.8982, -0.0106, -5.7931],
#         [-4.8840, -3.7673, -0.0312],
#         [-0.0481, -3.4702, -4.1453],
#         [-3.2980, -0.0459, -4.8388]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.02826577052474022
#
# tag_scores is
#
# tensor([[-4.7837, -0.0240, -4.1764],
#         [-4.8951, -3.4799, -0.0390],
#         [-0.0214, -4.1062, -5.3613],
#         [-4.5940, -0.0286, -4.0118]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.031304724514484406
#
# tag_scores is
#
# tensor([[-0.0218, -3.8872, -6.8776],
#         [-4.9055, -0.0105, -5.7979],
#         [-4.8907, -3.7719, -0.0310],
#         [-0.0477, -3.4791, -4.1525],
#         [-3.3056, -0.0456, -4.8434]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.0281000304967165
#
# tag_scores is
#
# tensor([[-4.7898, -0.0239, -4.1823],
#         [-4.9014, -3.4847, -0.0388],
#         [-0.0212, -4.1134, -5.3675],
#         [-4.6007, -0.0285, -4.0170]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.0310902688652277
#
# tag_scores is
#
# tensor([[-0.0217, -3.8922, -6.8842],
#         [-4.9128, -0.0104, -5.8027],
#         [-4.8973, -3.7766, -0.0308],
#         [-0.0473, -3.4879, -4.1597],
#         [-3.3132, -0.0453, -4.8479]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.02793612703680992
#
# tag_scores is
#
# tensor([[-4.7959, -0.0237, -4.1882],
#         [-4.9078, -3.4894, -0.0386],
#         [-0.0211, -4.1207, -5.3736],
#         [-4.6072, -0.0283, -4.0221]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.030878489837050438
#
# tag_scores is
#
# tensor([[-0.0215, -3.8972, -6.8908],
#         [-4.9200, -0.0104, -5.8075],
#         [-4.9039, -3.7812, -0.0307],
#         [-0.0469, -3.4967, -4.1668],
#         [-3.3208, -0.0449, -4.8525]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.027774006128311157
#
# tag_scores is
#
# tensor([[-4.8020, -0.0236, -4.1941],
#         [-4.9141, -3.4941, -0.0384],
#         [-0.0209, -4.1278, -5.3797],
#         [-4.6138, -0.0281, -4.0272]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.03066934086382389
#
# tag_scores is
#
# tensor([[-0.0214, -3.9022, -6.8973],
#         [-4.9272, -0.0103, -5.8123],
#         [-4.9105, -3.7858, -0.0305],
#         [-0.0465, -3.5054, -4.1740],
#         [-3.3283, -0.0446, -4.8570]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.027613651007413864
#
# tag_scores is
#
# tensor([[-4.8080, -0.0234, -4.1999],
#         [-4.9203, -3.4989, -0.0383],
#         [-0.0208, -4.1350, -5.3857],
#         [-4.6203, -0.0280, -4.0323]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.030462786555290222
#
# tag_scores is
#
# tensor([[-0.0213, -3.9072, -6.9038],
#         [-4.9344, -0.0102, -5.8170],
#         [-4.9170, -3.7903, -0.0304],
#         [-0.0461, -3.5141, -4.1810],
#         [-3.3357, -0.0443, -4.8614]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.0274550411850214
#
# tag_scores is
#
# tensor([[-4.8140, -0.0233, -4.2057],
#         [-4.9266, -3.5035, -0.0381],
#         [-0.0207, -4.1421, -5.3918],
#         [-4.6268, -0.0278, -4.0374]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.0302587803453207
#
# tag_scores is
#
# tensor([[-0.0212, -3.9121, -6.9102],
#         [-4.9415, -0.0102, -5.8217],
#         [-4.9235, -3.7949, -0.0302],
#         [-0.0457, -3.5227, -4.1881],
#         [-3.3432, -0.0440, -4.8659]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.027298133820295334
#
# tag_scores is
#
# tensor([[-4.8200, -0.0232, -4.2115],
#         [-4.9328, -3.5082, -0.0379],
#         [-0.0205, -4.1492, -5.3978],
#         [-4.6333, -0.0277, -4.0424]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# loss is
#
# 0.030057275667786598
#
# tag_scores is
#
# tensor([[-0.0211, -3.9171, -6.9167],
#         [-4.9485, -0.0101, -5.8264],
#         [-4.9300, -3.7994, -0.0301],
#         [-0.0453, -3.5313, -4.1951],
#         [-3.3506, -0.0437, -4.8703]])
# , targets is
#
# tensor([ 0,  1,  2,  0,  1])
#
# loss is
#
# 0.027142919600009918
#
# tag_scores is
#
# tensor([[-4.8259, -0.0230, -4.2172],
#         [-4.9389, -3.5129, -0.0377],
#         [-0.0204, -4.1562, -5.4037],
#         [-4.6397, -0.0275, -4.0474]])
# , targets is
#
# tensor([ 1,  2,  0,  1])
#
# tensor([[-0.0757, -2.6413, -6.4296],
#         [-5.2760, -0.0074, -6.0882],
#         [-4.9735, -3.7986, -0.0298],
#         [-0.0452, -3.5214, -4.2215],
#         [-3.3802, -0.0423, -4.9053]])
